# %%
import pandas as pd
import numpy as np
import glob as glob

# %%
files = glob.glob('C:/Users/Ahmed/upwork_viz/*.csv')

# %%
files
# Out:
# ['C:/Users/Ahmed/upwork_viz\\airbnb0.csv',
#  'C:/Users/Ahmed/upwork_viz\\airbnbtrial7.csv',
#  'C:/Users/Ahmed/upwork_viz\\listings(Chicago).csv',
#  'C:/Users/Ahmed/upwork_viz\\listings(new orelano).csv',
#  'C:/Users/Ahmed/upwork_viz\\neighbourhoods(Chicago).csv',
#  'C:/Users/Ahmed/upwork_viz\\neighbourhoods(new orelano).csv',
#  'C:/Users/Ahmed/upwork_viz\\reviews (Chicago).csv',
#  'C:/Users/Ahmed/upwork_viz\\reviews(new orelano).csv']

# %%
df1=pd.read_csv(files[2])
df2=pd.read_csv(files[3])
df=pd.concat([df1,df2])

# %%
df
# Out:
#                       id                                               name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df=df.drop(columns=['neighbourhood_group'])

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365',
#        'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
df['name'].unique()
# Out:
# array(['Condo in Chicago · ★4.99 · 1 bedroom · 1 bed · 1 shared bath',
#        'Rental unit in Chicago · ★4.70 · 1 bedroom · 1 bed · 1 bath',
#        'Rental unit in Chicago · ★4.65 · 2 bedrooms · 2 beds · 1 bath',
#        ..., 'Home in New Orleans · ★New · 2 bedrooms · 2 beds · 3 baths',
#        'Home in Terrytown · ★New · 4 bedrooms · 4 beds · 2 baths',
#        'Rental unit in New Orleans · ★New · 4 bedrooms · 5 beds · 2 baths'],
#       dtype=object)

# %%
df['name']
# Out:
# 0       Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1       Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2       Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3       Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4       Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
#                               ...
# 6778    Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779    Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780    Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781    Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782    Rental unit in New Orleans · ★New · 4 bedrooms...
# Name: name, Length: 15311, dtype: object

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       2650
# reviews_per_month                 2650
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           2430
# dtype: int64

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %%
df['reviews_per_month'].str.replace(null,'0')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df['reviews_per_month'].str.replace(null,'0')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
# ...

# %%
df['reviews_per_month']=df['reviews_per_month'].astype(str)

# %%
df['reviews_per_month']=df['reviews_per_month'].str.replace('nan','0')

# %%
df['reviews_per_month'].unique()
# Out:
# array(['2.15', '2.92', '0.63', '0.15', '0.26', '0.32', '1.2', '1.56',
#        '0.71', '0.87', '1.22', '0.75', '0.85', '4.27', '2.14', '0.03',
#        '0.18', '0.27', '0.21', '0.48', '0.46', '0.35', '0.36', '2.01',
#        '5.03', '1.59', '4.8', '2.88', '2.19', '0.41', '0.88', '1.38',
#        '0.78', '0.74', '1.27', '5.81', '1.73', '0.22', '1.06', '1.17',
#        '3.57', '1.04', '0', '3.25', '2.37', '2.62', '2.4', '2.03', '0.31',
#        '0.06', '0.11', '0.08', '0.66', '2.84', '1.68', '0.16', '0.99',
#        '0.93', '3.43', '0.24', '1.51', '0.14', '1.64', '5.01', '0.37',
#        '1.52', '3.02', '0.54', '3.28', '1.23', '1.21', '0.13', '1.13',
#        '0.82', '3.11', '0.49', '1.31', '2.89', '0.9', '0.12', '0.04',
#        '2.32', '1.75', '1.4', '1.7', '0.47', '3.96', '1.43', '4.14',
#        '2.24', '1.53', '0.96', '0.07', '0.05', '1.92', '2.17', '1.42',
#        '2.71', '3.08', '2.16', '4.02', '1.49', '1.16', '3.21', '2.13',
# ...

# %%
df['reviews_per_month']=df['reviews_per_month'].astype(float)

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       2650
# reviews_per_month                    0
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           2430
# dtype: int64

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365',
#        'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
df=df.drop(columns=['license'])

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df=df.rename(columns={'calculated_host_listings_count':'host_listings','last_review':'review_date'})

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'review_date', 'reviews_per_month',
#        'host_listings', 'availability_365', 'number_of_reviews_ltm'],
#       dtype='object')

# %%
df=df.drop(columns=['number_of_reviews_ltm'])

# %%
df
# Out:
#                       id                                               name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df['name']
# Out:
# 0       Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1       Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2       Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3       Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4       Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
#                               ...
# 6778    Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779    Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780    Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781    Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782    Rental unit in New Orleans · ★New · 4 bedrooms...
# Name: name, Length: 15311, dtype: object

# %%
prop=df['name'].str.split('·',expand=True)

# %%
prop
# Out:
#                                 0        1             2         3  \
# 0               Condo in Chicago    ★4.99     1 bedroom     1 bed
# 1         Rental unit in Chicago    ★4.70     1 bedroom     1 bed
# 2         Rental unit in Chicago    ★4.65    2 bedrooms    2 beds
# 3      Boutique hotel in Chicago    ★4.93     1 bedroom     1 bed
# 4         Rental unit in Chicago    ★4.29     1 bedroom     1 bed
# ...                           ...      ...           ...       ...
# 6778        Condo in New Orleans     ★New     1 bedroom    2 beds
# 6779  Rental unit in New Orleans     ★New     1 bedroom     1 bed
# 6780         Home in New Orleans     ★New    2 bedrooms    3 beds
# 6781         Home in New Orleans     ★New    3 bedrooms    3 beds
# 6782  Rental unit in New Orleans     ★New    4 bedrooms    5 beds
#
#                     4
# 0       1 shared bath
# 1              1 bath
# 2              1 bath
# 3      1 private bath
# 4              1 bath
# ...               ...
# ...

# %%
prop=prop.rename(columns={0:'details',1:'rating',2:'bedrooms',3:'beds',4:'baths'})

# %%
prop
# Out:
#                           details   rating      bedrooms      beds  \
# 0               Condo in Chicago    ★4.99     1 bedroom     1 bed
# 1         Rental unit in Chicago    ★4.70     1 bedroom     1 bed
# 2         Rental unit in Chicago    ★4.65    2 bedrooms    2 beds
# 3      Boutique hotel in Chicago    ★4.93     1 bedroom     1 bed
# 4         Rental unit in Chicago    ★4.29     1 bedroom     1 bed
# ...                           ...      ...           ...       ...
# 6778        Condo in New Orleans     ★New     1 bedroom    2 beds
# 6779  Rental unit in New Orleans     ★New     1 bedroom     1 bed
# 6780         Home in New Orleans     ★New    2 bedrooms    3 beds
# 6781         Home in New Orleans     ★New    3 bedrooms    3 beds
# 6782  Rental unit in New Orleans     ★New    4 bedrooms    5 beds
#
#                 baths
# 0       1 shared bath
# 1              1 bath
# 2              1 bath
# 3      1 private bath
# 4              1 bath
# ...               ...
# ...

# %%
info=prop['details'].str.split('in',expand=True)

# %%
prop['rating'].unique()
# Out:
# array([' ★4.99 ', ' ★4.70 ', ' ★4.65 ', ' ★4.93 ', ' ★4.29 ', ' ★4.30 ',
#        ' ★4.77 ', ' ★4.88 ', ' ★5.0 ', ' ★4.78 ', ' ★4.95 ', ' ★4.90 ',
#        ' ★4.91 ', ' ★4.84 ', ' ★4.74 ', ' ★4.96 ', ' ★4.85 ', ' ★4.52 ',
#        ' ★4.72 ', ' ★4.81 ', ' ★4.92 ', ' ★4.54 ', ' ★4.98 ', ' ★4.94 ',
#        ' ★4.87 ', ' ★4.66 ', ' ★4.26 ', ' 2 bedrooms ', ' ★4.97 ',
#        ' ★4.68 ', ' ★4.17 ', ' ★4.36 ', ' ★4.0 ', ' ★4.67 ', ' ★4.31 ',
#        ' ★4.64 ', ' ★4.43 ', ' ★4.61 ', ' ★4.60 ', ' ★4.40 ', ' ★New ',
#        ' ★4.89 ', ' ★4.83 ', ' ★4.82 ', ' ★4.75 ', ' ★4.71 ', ' ★4.79 ',
#        ' ★4.48 ', ' ★4.58 ', ' 1 bedroom ', ' ★4.69 ', ' ★4.47 ',
#        ' ★4.53 ', ' ★4.80 ', ' ★3.67 ', ' ★4.25 ', ' ★4.73 ', ' ★4.57 ',
#        ' ★4.49 ', ' ★4.86 ', ' ★4.55 ', ' ★4.76 ', ' ★4.38 ',
#        ' 3 bedrooms ', ' ★4.44 ', ' ★4.56 ', ' ★4.63 ', ' ★4.41 ',
#        ' ★4.62 ', ' ★4.45 ', ' Studio ', ' ★4.24 ', ' ★4.37 ', ' ★4.46 ',
# ...

# %%
prop['rating']=prop['rating'].str.replace('★','')

# %%
prop
# Out:
#                           details  rating      bedrooms      beds  \
# 0               Condo in Chicago    4.99     1 bedroom     1 bed
# 1         Rental unit in Chicago    4.70     1 bedroom     1 bed
# 2         Rental unit in Chicago    4.65    2 bedrooms    2 beds
# 3      Boutique hotel in Chicago    4.93     1 bedroom     1 bed
# 4         Rental unit in Chicago    4.29     1 bedroom     1 bed
# ...                           ...     ...           ...       ...
# 6778        Condo in New Orleans     New     1 bedroom    2 beds
# 6779  Rental unit in New Orleans     New     1 bedroom     1 bed
# 6780         Home in New Orleans     New    2 bedrooms    3 beds
# 6781         Home in New Orleans     New    3 bedrooms    3 beds
# 6782  Rental unit in New Orleans     New    4 bedrooms    5 beds
#
#                 baths
# 0       1 shared bath
# 1              1 bath
# 2              1 bath
# 3      1 private bath
# 4              1 bath
# ...               ...
# ...

# %%
prop['rating']=prop['rating'].str.replace('New','0')

# %%
prop
# Out:
#                           details  rating      bedrooms      beds  \
# 0               Condo in Chicago    4.99     1 bedroom     1 bed
# 1         Rental unit in Chicago    4.70     1 bedroom     1 bed
# 2         Rental unit in Chicago    4.65    2 bedrooms    2 beds
# 3      Boutique hotel in Chicago    4.93     1 bedroom     1 bed
# 4         Rental unit in Chicago    4.29     1 bedroom     1 bed
# ...                           ...     ...           ...       ...
# 6778        Condo in New Orleans       0     1 bedroom    2 beds
# 6779  Rental unit in New Orleans       0     1 bedroom     1 bed
# 6780         Home in New Orleans       0    2 bedrooms    3 beds
# 6781         Home in New Orleans       0    3 bedrooms    3 beds
# 6782  Rental unit in New Orleans       0    4 bedrooms    5 beds
#
#                 baths
# 0       1 shared bath
# 1              1 bath
# 2              1 bath
# 3      1 private bath
# 4              1 bath
# ...               ...
# ...

# %%
info
# Out:
#                     0              1     2
# 0              Condo        Chicago   None
# 1        Rental unit        Chicago   None
# 2        Rental unit        Chicago   None
# 3     Boutique hotel        Chicago   None
# 4        Rental unit        Chicago   None
# ...               ...            ...   ...
# 6778           Condo    New Orleans   None
# 6779     Rental unit    New Orleans   None
# 6780            Home    New Orleans   None
# 6781            Home    New Orleans   None
# 6782     Rental unit    New Orleans   None
#
# [15311 rows x 3 columns]

# %%
info=info.rename(columns={1:'city'})

# %%
info
# Out:
#                     0           city     2
# 0              Condo        Chicago   None
# 1        Rental unit        Chicago   None
# 2        Rental unit        Chicago   None
# 3     Boutique hotel        Chicago   None
# 4        Rental unit        Chicago   None
# ...               ...            ...   ...
# 6778           Condo    New Orleans   None
# 6779     Rental unit    New Orleans   None
# 6780            Home    New Orleans   None
# 6781            Home    New Orleans   None
# 6782     Rental unit    New Orleans   None
#
# [15311 rows x 3 columns]

# %%
info=info.rename(columns={0:'property_type'})

# %%
info
# Out:
#         property_type           city     2
# 0              Condo        Chicago   None
# 1        Rental unit        Chicago   None
# 2        Rental unit        Chicago   None
# 3     Boutique hotel        Chicago   None
# 4        Rental unit        Chicago   None
# ...               ...            ...   ...
# 6778           Condo    New Orleans   None
# 6779     Rental unit    New Orleans   None
# 6780            Home    New Orleans   None
# 6781            Home    New Orleans   None
# 6782     Rental unit    New Orleans   None
#
# [15311 rows x 3 columns]

# %%
info[2].unique()
# Out:
# array([None, ' Chicago ', ' New Orleans ', ' Gretna '], dtype=object)

# %%
info=info.rename(columns={2:'city_2'})

# %%
df['name']=info['property_type']

# %%
df
# Out:
#                       id             name    host_id  \
# 0                   2384           Condo        2613
# 1                   7126     Rental unit       17928
# 2                  10945     Rental unit       33004
# 3                  12140  Boutique hotel       46734
# 4                  24833     Rental unit      101521
# ...                  ...              ...        ...
# 6778  970848339775836367           Condo   442915263
# 6779  971022630551974985     Rental unit   428276486
# 6780  971622427724347438            Home    68337970
# 6781  971690279215450436            Home    14988904
# 6782  971756233356699947     Rental unit    33076245
#
#                          host_name              neighbourhood   latitude  \
# 0                          Rebecca                  Hyde Park  41.787900
# 1                            Sarah                  West Town  41.901660
# 2                      At Home Inn               Lincoln Park  41.911960
# ...

# %%
df=df.rename(columns={'name':'property_type'})

# %%
df
# Out:
#                       id    property_type    host_id  \
# 0                   2384           Condo        2613
# 1                   7126     Rental unit       17928
# 2                  10945     Rental unit       33004
# 3                  12140  Boutique hotel       46734
# 4                  24833     Rental unit      101521
# ...                  ...              ...        ...
# 6778  970848339775836367           Condo   442915263
# 6779  971022630551974985     Rental unit   428276486
# 6780  971622427724347438            Home    68337970
# 6781  971690279215450436            Home    14988904
# 6782  971756233356699947     Rental unit    33076245
#
#                          host_name              neighbourhood   latitude  \
# 0                          Rebecca                  Hyde Park  41.787900
# 1                            Sarah                  West Town  41.901660
# 2                      At Home Inn               Lincoln Park  41.911960
# ...

# %%
info
# Out:
#         property_type           city city_2
# 0              Condo        Chicago    None
# 1        Rental unit        Chicago    None
# 2        Rental unit        Chicago    None
# 3     Boutique hotel        Chicago    None
# 4        Rental unit        Chicago    None
# ...               ...            ...    ...
# 6778           Condo    New Orleans    None
# 6779     Rental unit    New Orleans    None
# 6780            Home    New Orleans    None
# 6781            Home    New Orleans    None
# 6782     Rental unit    New Orleans    None
#
# [15311 rows x 3 columns]

# %%
df['city']=info['city']

# %%
df['city_2']=info['city_2']

# %%
prop
# Out:
#                           details  rating      bedrooms      beds  \
# 0               Condo in Chicago    4.99     1 bedroom     1 bed
# 1         Rental unit in Chicago    4.70     1 bedroom     1 bed
# 2         Rental unit in Chicago    4.65    2 bedrooms    2 beds
# 3      Boutique hotel in Chicago    4.93     1 bedroom     1 bed
# 4         Rental unit in Chicago    4.29     1 bedroom     1 bed
# ...                           ...     ...           ...       ...
# 6778        Condo in New Orleans       0     1 bedroom    2 beds
# 6779  Rental unit in New Orleans       0     1 bedroom     1 bed
# 6780         Home in New Orleans       0    2 bedrooms    3 beds
# 6781         Home in New Orleans       0    3 bedrooms    3 beds
# 6782  Rental unit in New Orleans       0    4 bedrooms    5 beds
#
#                 baths
# 0       1 shared bath
# 1              1 bath
# 2              1 bath
# 3      1 private bath
# 4              1 bath
# ...               ...
# ...

# %%
df['rating']=prop['rating']
df['bedrooms']=prop['bedrooms']
df['baths']=prop['baths']

# %%
df
# Out:
#                       id    property_type    host_id  \
# 0                   2384           Condo        2613
# 1                   7126     Rental unit       17928
# 2                  10945     Rental unit       33004
# 3                  12140  Boutique hotel       46734
# 4                  24833     Rental unit      101521
# ...                  ...              ...        ...
# 6778  970848339775836367           Condo   442915263
# 6779  971022630551974985     Rental unit   428276486
# 6780  971622427724347438            Home    68337970
# 6781  971690279215450436            Home    14988904
# 6782  971756233356699947     Rental unit    33076245
#
#                          host_name              neighbourhood   latitude  \
# 0                          Rebecca                  Hyde Park  41.787900
# 1                            Sarah                  West Town  41.901660
# 2                      At Home Inn               Lincoln Park  41.911960
# ...

# %%
df.to_csv('Airbnb_insights_Final.csv', index=False)
