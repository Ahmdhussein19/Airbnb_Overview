# %%
import pandas as pd

# %%
import glob as glob

# %%
files = glob.glob('C:/Users/Ahmed/upwork_viz/*.csv')

# %%
files
# Out:
# ['C:/Users/Ahmed/upwork_viz\\listings (Chicago).csv',
#  'C:/Users/Ahmed/upwork_viz\\listings(new orelano).csv',
#  'C:/Users/Ahmed/upwork_viz\\neighbourhoods(Chicago).csv',
#  'C:/Users/Ahmed/upwork_viz\\neighbourhoods(new orelano).csv',
#  'C:/Users/Ahmed/upwork_viz\\reviews (Chicago).csv',
#  'C:/Users/Ahmed/upwork_viz\\reviews(new orelano).csv']

# %%
pd.read_csv(files[0]).columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
pd.read_csv(files[1]).columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
data=pd.DataFrame()

for file in files:
    df=pd.read_csv(files[0],files[1])
    df1=pd.concat([df1,df])
data
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_15512\1656043863.py:4: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   df=pd.read_csv(files[0],files[1])
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_15512\1656043863.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df=pd.read_csv(files[0],files[1])
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[18], line 4
#       1 data=pd.DataFrame()
#       3 for file in files:
# ----> 4     df=pd.read_csv(files[0],files[1])
#       5     df1=pd.concat([df1,df])
#       6 data
#
# ...

# %%
df=pd.read_csv(files[0])
df1=pd.read_csv(files[1])
data=pd.concat([df,df1])

# %%
data.shape
# Out:
# (15311, 18)

# %%
df.shape
# Out:
# (8528, 18)

# %%
df1.shape
# Out:
# (6783, 18)

# %%
data
# Out:
#                       id                                               name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
data['name']
# Out:
# 0       Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1       Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2       Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3       Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4       Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
#                               ...
# 6778    Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779    Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780    Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781    Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782    Rental unit in New Orleans · ★New · 4 bedrooms...
# Name: name, Length: 15311, dtype: object

# %%
data.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %%
specs = data['name'].str.split('·', expand=True)

# %%
specs
# Out:
#                                 0        1             2         3  \
# 0               Condo in Chicago    ★4.99     1 bedroom     1 bed
# 1         Rental unit in Chicago    ★4.70     1 bedroom     1 bed
# 2         Rental unit in Chicago    ★4.65    2 bedrooms    2 beds
# 3      Boutique hotel in Chicago    ★4.93     1 bedroom     1 bed
# 4         Rental unit in Chicago    ★4.29     1 bedroom     1 bed
# ...                           ...      ...           ...       ...
# 6778        Condo in New Orleans     ★New     1 bedroom    2 beds
# 6779  Rental unit in New Orleans     ★New     1 bedroom     1 bed
# 6780         Home in New Orleans     ★New    2 bedrooms    3 beds
# 6781         Home in New Orleans     ★New    3 bedrooms    3 beds
# 6782  Rental unit in New Orleans     ★New    4 bedrooms    5 beds
#
#                     4
# 0       1 shared bath
# 1              1 bath
# 2              1 bath
# 3      1 private bath
# 4              1 bath
# ...               ...
# ...

# %%
specs=specs.rename(columns={0 : 'Name', 1:'Rate',})

# %%
specs
# Out:
#                              Name     Rate             2         3  \
# 0               Condo in Chicago    ★4.99     1 bedroom     1 bed
# 1         Rental unit in Chicago    ★4.70     1 bedroom     1 bed
# 2         Rental unit in Chicago    ★4.65    2 bedrooms    2 beds
# 3      Boutique hotel in Chicago    ★4.93     1 bedroom     1 bed
# 4         Rental unit in Chicago    ★4.29     1 bedroom     1 bed
# ...                           ...      ...           ...       ...
# 6778        Condo in New Orleans     ★New     1 bedroom    2 beds
# 6779  Rental unit in New Orleans     ★New     1 bedroom     1 bed
# 6780         Home in New Orleans     ★New    2 bedrooms    3 beds
# 6781         Home in New Orleans     ★New    3 bedrooms    3 beds
# 6782  Rental unit in New Orleans     ★New    4 bedrooms    5 beds
#
#                     4
# 0       1 shared bath
# 1              1 bath
# 2              1 bath
# 3      1 private bath
# 4              1 bath
# ...               ...
# ...

# %%
specs.dtypes
# Out:
# Name    object
# Rate    object
# 2       object
# 3       object
# 4       object
# dtype: object

# %%
specis = specs[2] + '|' + specs[3] + '|' + specs[4]

# %%
specis
# Out:
# 0         1 bedroom | 1 bed | 1 shared bath
# 1                1 bedroom | 1 bed | 1 bath
# 2              2 bedrooms | 2 beds | 1 bath
# 3        1 bedroom | 1 bed | 1 private bath
# 4                1 bedroom | 1 bed | 1 bath
#                        ...
# 6778            1 bedroom | 2 beds | 1 bath
# 6779             1 bedroom | 1 bed | 1 bath
# 6780          2 bedrooms | 3 beds | 2 baths
# 6781          3 bedrooms | 3 beds | 2 baths
# 6782          4 bedrooms | 5 beds | 2 baths
# Length: 15311, dtype: object

# %%
specs
# Out:
#                              Name     Rate             2         3  \
# 0               Condo in Chicago    ★4.99     1 bedroom     1 bed
# 1         Rental unit in Chicago    ★4.70     1 bedroom     1 bed
# 2         Rental unit in Chicago    ★4.65    2 bedrooms    2 beds
# 3      Boutique hotel in Chicago    ★4.93     1 bedroom     1 bed
# 4         Rental unit in Chicago    ★4.29     1 bedroom     1 bed
# ...                           ...      ...           ...       ...
# 6778        Condo in New Orleans     ★New     1 bedroom    2 beds
# 6779  Rental unit in New Orleans     ★New     1 bedroom     1 bed
# 6780         Home in New Orleans     ★New    2 bedrooms    3 beds
# 6781         Home in New Orleans     ★New    3 bedrooms    3 beds
# 6782  Rental unit in New Orleans     ★New    4 bedrooms    5 beds
#
#                     4
# 0       1 shared bath
# 1              1 bath
# 2              1 bath
# 3      1 private bath
# 4              1 bath
# ...               ...
# ...

# %%
specs=specs.rename(columns={'Name':'name','Rate':'rating'})

# %%
specs
# Out:
#                              name   rating      bedrooms      beds  \
# 0               Condo in Chicago    ★4.99     1 bedroom     1 bed
# 1         Rental unit in Chicago    ★4.70     1 bedroom     1 bed
# 2         Rental unit in Chicago    ★4.65    2 bedrooms    2 beds
# 3      Boutique hotel in Chicago    ★4.93     1 bedroom     1 bed
# 4         Rental unit in Chicago    ★4.29     1 bedroom     1 bed
# ...                           ...      ...           ...       ...
# 6778        Condo in New Orleans     ★New     1 bedroom    2 beds
# 6779  Rental unit in New Orleans     ★New     1 bedroom     1 bed
# 6780         Home in New Orleans     ★New    2 bedrooms    3 beds
# 6781         Home in New Orleans     ★New    3 bedrooms    3 beds
# 6782  Rental unit in New Orleans     ★New    4 bedrooms    5 beds
#
#                 baths
# 0       1 shared bath
# 1              1 bath
# 2              1 bath
# 3      1 private bath
# 4              1 bath
# ...               ...
# ...

# %%
data['name']=specs['name']

# %%
data['rating']=specs['rating']
data['bedrooms']=specs['bedrooms']
data['beds']=specs['beds']
data['baths']=specs['baths']

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths'],
#       dtype='object')

# %%
titles=list(data.columns)

# %%
titles
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'number_of_reviews_ltm',
#  'license',
#  'rating',
#  'bedrooms',
#  'beds',
#  'baths']

# %%
data.shape
# Out:
# (15311, 22)

# %%
titles[3],titles[19]=titles[19],titles[3]

# %%
titles
# Out:
# ['id',
#  'name',
#  'host_id',
#  'bedrooms',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'number_of_reviews_ltm',
#  'license',
#  'rating',
#  'bedrooms',
#  'beds',
#  'baths']

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
titles
# Out:
# ['id',
#  'name',
#  'host_id',
#  'bedrooms',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'number_of_reviews_ltm',
#  'license',
#  'rating',
#  'bedrooms',
#  'beds',
#  'baths']

# %%
titles[2],titles[3]=titles[3],titles[2]

# %%
titles
# Out:
# ['id',
#  'name',
#  'bedrooms',
#  'host_id',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'number_of_reviews_ltm',
#  'license',
#  'rating',
#  'bedrooms',
#  'beds',
#  'baths']

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths'],
#       dtype='object')

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
data.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# rating                             object
# bedrooms                           object
# beds                               object
# baths                              object
# dtype: object

# %%
data['last_review']=pd.to_datetime(data['last_review'])

# %%
data['last_review']
# Out:
# 0       2023-09-03
# 1       2023-08-30
# 2       2023-08-29
# 3       2023-05-21
# 4       2023-04-22
#            ...
# 6778           NaN
# 6779           NaN
# 6780           NaN
# 6781           NaN
# 6782           NaN
# Name: last_review, Length: 15311, dtype: object

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
data['reviews_per_month']=data['reviews_per_month'].fillna(0)

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data.plot()
# Out:
# <Axes: >
# Error in callback <function _draw_all_if_interactive at 0x000002F9C1421620> (for post_execute):
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:120, in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:2082, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2080 if not self._is_idle_drawing:
#    2081     with self._idle_draw_cntx():
# -> 2082         self.draw(*args, **kwargs)
#
# ...

# %%
data.plot(kind = 'line', xlabel='room_type', ylabel='price')
# Out:
# <Axes: xlabel='room_type', ylabel='price'>
# Error in callback <function _draw_all_if_interactive at 0x000002F9C1421620> (for post_execute):
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:120, in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:2082, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2080 if not self._is_idle_drawing:
#    2081     with self._idle_draw_cntx():
# ...

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#                  id       host_id  neighbourhood_group      latitude  \
# count  1.531100e+04  1.531100e+04                  0.0  15311.000000
# mean   3.290655e+17  1.755173e+08                  NaN     36.605550
# std    3.902640e+17  1.644326e+08                  NaN      5.928168
# min    2.384000e+03  9.710000e+02                  NaN     29.897680
# 25%    3.000865e+07  3.494976e+07                  NaN     29.963850
# 50%    5.087212e+07  1.074344e+08                  NaN     41.799537
# 75%    7.353523e+17  2.987698e+08                  NaN     41.900809
# max    9.782649e+17  5.365148e+08                  NaN     42.022200
#
#           longitude         price  minimum_nights  number_of_reviews  \
# count  15311.000000  15311.000000    15311.000000       15311.000000
# mean     -88.730493    198.546209       15.527595          54.769643
# std        1.198975    278.890457       32.824771          91.206256
# ...

# %%
data['id'].max()
# Out:
# 978264935480956783

# %%
data.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group               15311
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        2650
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                            2430
# rating                                0
# bedrooms                              0
# beds                                 32
# baths                              3333
# dtype: int64

# %%
data[data.isna()]
# Out:
#       id name  host_id host_name  neighbourhood_group neighbourhood  latitude  \
# 0    NaN  NaN      NaN       NaN                  NaN           NaN       NaN
# 1    NaN  NaN      NaN       NaN                  NaN           NaN       NaN
# 2    NaN  NaN      NaN       NaN                  NaN           NaN       NaN
# 3    NaN  NaN      NaN       NaN                  NaN           NaN       NaN
# 4    NaN  NaN      NaN       NaN                  NaN           NaN       NaN
# ...   ..  ...      ...       ...                  ...           ...       ...
# 6778 NaN  NaN      NaN       NaN                  NaN           NaN       NaN
# 6779 NaN  NaN      NaN       NaN                  NaN           NaN       NaN
# 6780 NaN  NaN      NaN       NaN                  NaN           NaN       NaN
# 6781 NaN  NaN      NaN       NaN                  NaN           NaN       NaN
# 6782 NaN  NaN      NaN       NaN                  NaN           NaN       NaN
#
# ...

# %%
data.shape
# Out:
# (15311, 22)

# %%
data.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                      float64
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                      int64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# number_of_reviews_ltm                      int64
# license                                   object
# rating                                    object
# ...

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
bedroom=data['bedrooms'].str.split('b',expand=True)

# %%
bedroom=bedroom.drop(columns=[1])

# %%
bedroom=bedroom.rename(columns={0:'bedrooms'})

# %%
bedroom
# Out:
#      bedrooms
# 0          1
# 1          1
# 2          2
# 3          1
# 4          1
# ...       ...
# 6778       1
# 6779       1
# 6780       2
# 6781       3
# 6782       4
#
# [15311 rows x 1 columns]

# %%
data['bedrooms']=bedroom

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
bed=data['beds'].str.split('b',expand=True)
bed=bed.drop(columns=[1])
bed=bed.rename(columns={0:'beds'})

# %%
beds = bed

# %%
data['beds']=beds

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
bath=data['baths'].str.split('b', expand=True)

# %%
bath[0].str.split('s', expand=True)
baths_number = bath[0]

# %%
bath
# Out:
#                 0     1
# 0       1 shared    ath
# 1              1    ath
# 2              1    ath
# 3      1 private    ath
# 4              1    ath
# ...           ...   ...
# 6778           1    ath
# 6779           1    ath
# 6780           2   aths
# 6781           2   aths
# 6782           2   aths
#
# [15311 rows x 2 columns]

# %%
bath
# Out:
#                 0     1
# 0       1 shared    ath
# 1              1    ath
# 2              1    ath
# 3      1 private    ath
# 4              1    ath
# ...           ...   ...
# 6778           1    ath
# 6779           1    ath
# 6780           2   aths
# 6781           2   aths
# 6782           2   aths
#
# [15311 rows x 2 columns]

# %%
baths_number
# Out:
# 0         1 shared
# 1                1
# 2                1
# 3        1 private
# 4                1
#            ...
# 6778             1
# 6779             1
# 6780             2
# 6781             2
# 6782             2
# Name: 0, Length: 15311, dtype: object

# %%
baths_number=baths_number.str.split('s', expand=True)

# %%
baths_number
# Out:
#                 0       1
# 0              1   hared
# 1              1     None
# 2              1     None
# 3      1 private     None
# 4              1     None
# ...           ...     ...
# 6778           1     None
# 6779           1     None
# 6780           2     None
# 6781           2     None
# 6782           2     None
#
# [15311 rows x 2 columns]

# %%
baths_number=baths_number[0].str.split('p', expand=True)

# %%
baths_number
# Out:
#         0        1
# 0      1      None
# 1      1      None
# 2      1      None
# 3      1   rivate
# 4      1      None
# ...   ...      ...
# 6778   1      None
# 6779   1      None
# 6780   2      None
# 6781   2      None
# 6782   2      None
#
# [15311 rows x 2 columns]

# %%
baths
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 baths
#
# NameError: name 'baths' is not defined

# %%
bath
# Out:
#                 0     1
# 0       1 shared    ath
# 1              1    ath
# 2              1    ath
# 3      1 private    ath
# 4              1    ath
# ...           ...   ...
# 6778           1    ath
# 6779           1    ath
# 6780           2   aths
# 6781           2   aths
# 6782           2   aths
#
# [15311 rows x 2 columns]

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
data.to_csv('Airbnb_combined.csv', index=False)

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
data.isna()
# Out:
#          id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0     False  False    False      False                 True          False
# 1     False  False    False      False                 True          False
# 2     False  False    False      False                 True          False
# 3     False  False    False      False                 True          False
# 4     False  False    False      False                 True          False
# ...     ...    ...      ...        ...                  ...            ...
# 6778  False  False    False      False                 True          False
# 6779  False  False    False      False                 True          False
# 6780  False  False    False      False                 True          False
# 6781  False  False    False      False                 True          False
# 6782  False  False    False      False                 True          False
#
#       latitude  longitude  room_type  price  ...  last_review  \
# ...

# %%
data.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group               15311
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        2650
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                            2430
# rating                                0
# bedrooms                              0
# beds                                 32
# baths                              3333
# dtype: int64

# %%
data.shape
# Out:
# (15311, 22)

# %%
location=data['name'].str.split('in',expand=True)

# %%
location
# Out:
#                     0              1     2
# 0              Condo        Chicago   None
# 1        Rental unit        Chicago   None
# 2        Rental unit        Chicago   None
# 3     Boutique hotel        Chicago   None
# 4        Rental unit        Chicago   None
# ...               ...            ...   ...
# 6778           Condo    New Orleans   None
# 6779     Rental unit    New Orleans   None
# 6780            Home    New Orleans   None
# 6781            Home    New Orleans   None
# 6782     Rental unit    New Orleans   None
#
# [15311 rows x 3 columns]

# %%
location.isna().sum()
# Out:
# 0        0
# 1        0
# 2    15283
# dtype: int64

# %%
location=location.drop(columns=[2])

# %%
location
# Out:
#                     0              1
# 0              Condo        Chicago
# 1        Rental unit        Chicago
# 2        Rental unit        Chicago
# 3     Boutique hotel        Chicago
# 4        Rental unit        Chicago
# ...               ...            ...
# 6778           Condo    New Orleans
# 6779     Rental unit    New Orleans
# 6780            Home    New Orleans
# 6781            Home    New Orleans
# 6782     Rental unit    New Orleans
#
# [15311 rows x 2 columns]

# %%
location=location.rename(columns={0:'name',1:'city'})

# %%
location
# Out:
#                  name           city
# 0              Condo        Chicago
# 1        Rental unit        Chicago
# 2        Rental unit        Chicago
# 3     Boutique hotel        Chicago
# 4        Rental unit        Chicago
# ...               ...            ...
# 6778           Condo    New Orleans
# 6779     Rental unit    New Orleans
# 6780            Home    New Orleans
# 6781            Home    New Orleans
# 6782     Rental unit    New Orleans
#
# [15311 rows x 2 columns]

# %%
data['name']=location['name']
# Out:
# 0                 Condo in Chicago
# 1           Rental unit in Chicago
# 2           Rental unit in Chicago
# 3        Boutique hotel in Chicago
# 4           Rental unit in Chicago
#                    ...
# 6778          Condo in New Orleans
# 6779    Rental unit in New Orleans
# 6780           Home in New Orleans
# 6781           Home in New Orleans
# 6782    Rental unit in New Orleans
# Name: name, Length: 15311, dtype: object

# %%
location['name']
# Out:
# 0                Condo
# 1          Rental unit
# 2          Rental unit
# 3       Boutique hotel
# 4          Rental unit
#              ...
# 6778             Condo
# 6779       Rental unit
# 6780              Home
# 6781              Home
# 6782       Rental unit
# Name: name, Length: 15311, dtype: object

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
data['city']=location['city']

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
data['city'].unique()
# Out:
# array([' Chicago ', ' Evanston ', ' Pilsen, Chicago ', ' Oak Park ',
#        ' Chicago Heights ', ' Chicago  ', ' Calumet Park ', 'y home ',
#        ' Bucktown, Chicago ', ' Oak Lawn ', ' Chicago, IL ',
#        ' Rogers Park ', ' Santa Barbara ', ' Harwood Heights ', ' 芝加哥 ',
#        ' Evergreen Park ', ' Berwyn ', ' The Bronx ', ' ', ' Norridge ',
#        'su ', ' Riverdale ', ' Elmwood Park ', ' New Orleans ', ' Arabi ',
#        '  Uptown, New Orleans ', ' Waggaman ', 'g ',
#        ' ByWater-Marigny, New Orleans ',
#        ' ByWater-Marigny, New Orleans  ', ' New Orleans, Louisiana, US ',
#        ' New orleans ', ' New Orleans, Louisiana ', ' New Orleans, ',
#        ' New Orleans  ', ' Gretna ', ' Terrytown '], dtype=object)

# %%
location['city'].unique()
# Out:
# array([' Chicago ', ' Evanston ', ' Pilsen, Chicago ', ' Oak Park ',
#        ' Chicago Heights ', ' Chicago  ', ' Calumet Park ', 'y home ',
#        ' Bucktown, Chicago ', ' Oak Lawn ', ' Chicago, IL ',
#        ' Rogers Park ', ' Santa Barbara ', ' Harwood Heights ', ' 芝加哥 ',
#        ' Evergreen Park ', ' Berwyn ', ' The Bronx ', ' ', ' Norridge ',
#        'su ', ' Riverdale ', ' Elmwood Park ', ' New Orleans ', ' Arabi ',
#        '  Uptown, New Orleans ', ' Waggaman ', 'g ',
#        ' ByWater-Marigny, New Orleans ',
#        ' ByWater-Marigny, New Orleans  ', ' New Orleans, Louisiana, US ',
#        ' New orleans ', ' New Orleans, Louisiana ', ' New Orleans, ',
#        ' New Orleans  ', ' Gretna ', ' Terrytown '], dtype=object)

# %%
data['name'].unique()
# Out:
# array(['Condo in Chicago ', 'Rental unit in Chicago ',
#        'Boutique hotel in Chicago ', 'Loft in Chicago ',
#        'Home in Chicago ', 'Place to stay in Chicago ',
#        'Guest suite in Chicago ', 'Rental unit in Evanston ',
#        'Hostel in Chicago ', 'Bungalow in Chicago ',
#        'Townhouse in Chicago ', 'Serviced apartment in Chicago ',
#        'Aparthotel in Chicago ', 'Guesthouse in Chicago ',
#        'Rental unit in Pilsen, Chicago ', 'Home in Oak Park ',
#        'Farm stay in Chicago ', 'Rental unit in Chicago Heights ',
#        'Hostel in Chicago  ', 'Bed and breakfast in Chicago ',
#        'Cottage in Chicago ', 'Rental unit in Calumet Park ',
#        'Rental unit in Chicago  ', 'Tiny home in Chicago ',
#        'Home in Bucktown, Chicago ', 'Home in Oak Lawn ',
#        'Serviced apartment in Chicago, IL ', 'Townhouse in Chicago  ',
#        'Townhouse in Calumet Park ', 'Hotel in Chicago ',
# ...

# %%
data['name']=data['name'].str.replace('a7a','Chicago')

# %%
data[data['name']=='a7a']
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm, license, rating, bedrooms, beds, baths, city]
# Index: []
#
# [0 rows x 23 columns]

# %%
data[data['name']=='Condo in Chicago']
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm, license, rating, bedrooms, beds, baths, city]
# Index: []
#
# [0 rows x 23 columns]

# %%
data['name'].unique()
# Out:
# array(['Condo in Chicago ', 'Rental unit in Chicago ',
#        'Boutique hotel in Chicago ', 'Loft in Chicago ',
#        'Home in Chicago ', 'Place to stay in Chicago ',
#        'Guest suite in Chicago ', 'Rental unit in Evanston ',
#        'Hostel in Chicago ', 'Bungalow in Chicago ',
#        'Townhouse in Chicago ', 'Serviced apartment in Chicago ',
#        'Aparthotel in Chicago ', 'Guesthouse in Chicago ',
#        'Rental unit in Pilsen, Chicago ', 'Home in Oak Park ',
#        'Farm stay in Chicago ', 'Rental unit in Chicago Heights ',
#        'Hostel in Chicago  ', 'Bed and breakfast in Chicago ',
#        'Cottage in Chicago ', 'Rental unit in Calumet Park ',
#        'Rental unit in Chicago  ', 'Tiny home in Chicago ',
#        'Home in Bucktown, Chicago ', 'Home in Oak Lawn ',
#        'Serviced apartment in Chicago, IL ', 'Townhouse in Chicago  ',
#        'Townhouse in Calumet Park ', 'Hotel in Chicago ',
# ...

# %%
data['name'].unique()
# Out:
# array(['Condo in Chicago ', 'Rental unit in Chicago ',
#        'Boutique hotel in Chicago ', 'Loft in Chicago ',
#        'Home in Chicago ', 'Place to stay in Chicago ',
#        'Guest suite in Chicago ', 'Rental unit in Evanston ',
#        'Hostel in Chicago ', 'Bungalow in Chicago ',
#        'Townhouse in Chicago ', 'Serviced apartment in Chicago ',
#        'Aparthotel in Chicago ', 'Guesthouse in Chicago ',
#        'Rental unit in Pilsen, Chicago ', 'Home in Oak Park ',
#        'Farm stay in Chicago ', 'Rental unit in Chicago Heights ',
#        'Hostel in Chicago  ', 'Bed and breakfast in Chicago ',
#        'Cottage in Chicago ', 'Rental unit in Calumet Park ',
#        'Rental unit in Chicago  ', 'Tiny home in Chicago ',
#        'Home in Bucktown, Chicago ', 'Home in Oak Lawn ',
#        'Serviced apartment in Chicago, IL ', 'Townhouse in Chicago  ',
#        'Townhouse in Calumet Park ', 'Hotel in Chicago ',
# ...

# %%
data[data['name']=='Home in New Orleans']
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm, license, rating, bedrooms, beds, baths, city]
# Index: []
#
# [0 rows x 23 columns]

# %%
df=data.drop(columns=['neighbourhood_group'])

# %%
df
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name              neighbourhood   latitude  \
# 0                          Rebecca                  Hyde Park  41.787900
# ...

# %%
df[df['name']=='Home in New Orleans']
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm, license, rating, bedrooms, beds, baths, city]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                      int64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# number_of_reviews_ltm                      int64
# license                                   object
# rating                                    object
# bedrooms                                  object
# ...

# %%
location
# Out:
#                  name           city
# 0              Condo        Chicago
# 1        Rental unit        Chicago
# 2        Rental unit        Chicago
# 3     Boutique hotel        Chicago
# 4        Rental unit        Chicago
# ...               ...            ...
# 6778           Condo    New Orleans
# 6779     Rental unit    New Orleans
# 6780            Home    New Orleans
# 6781            Home    New Orleans
# 6782     Rental unit    New Orleans
#
# [15311 rows x 2 columns]

# %%
location['city'].unique()
# Out:
# array([' Chicago ', ' Evanston ', ' Pilsen, Chicago ', ' Oak Park ',
#        ' Chicago Heights ', ' Chicago  ', ' Calumet Park ', 'y home ',
#        ' Bucktown, Chicago ', ' Oak Lawn ', ' Chicago, IL ',
#        ' Rogers Park ', ' Santa Barbara ', ' Harwood Heights ', ' 芝加哥 ',
#        ' Evergreen Park ', ' Berwyn ', ' The Bronx ', ' ', ' Norridge ',
#        'su ', ' Riverdale ', ' Elmwood Park ', ' New Orleans ', ' Arabi ',
#        '  Uptown, New Orleans ', ' Waggaman ', 'g ',
#        ' ByWater-Marigny, New Orleans ',
#        ' ByWater-Marigny, New Orleans  ', ' New Orleans, Louisiana, US ',
#        ' New orleans ', ' New Orleans, Louisiana ', ' New Orleans, ',
#        ' New Orleans  ', ' Gretna ', ' Terrytown '], dtype=object)

# %%
location[location['city']=='g ']
# Out:
#                 name city
# 408  Religious build   g

# %%
df.loc[408,'name']
# Out:
# 408               Rental unit in Chicago
# 408    Religious building in New Orleans
# Name: name, dtype: object

# %%
df.head(410)
# Out:
#           id                        name   host_id        host_name  \
# 0       2384           Condo in Chicago       2613          Rebecca
# 1       7126     Rental unit in Chicago      17928            Sarah
# 2      10945     Rental unit in Chicago      33004      At Home Inn
# 3      12140  Boutique hotel in Chicago      46734  Shay And Robert
# 4      24833     Rental unit in Chicago     101521              Red
# ..       ...                         ...       ...              ...
# 405  8615657     Rental unit in Chicago   45172634           Justin
# 406  8617633       Townhouse in Chicago   45333620              Rob
# 407  8633981     Rental unit in Chicago    3965428              Rob
# 408  8635380     Rental unit in Chicago    3965428              Rob
# 409  8689532     Rental unit in Chicago    9339313             Leon
#
#        neighbourhood   latitude  longitude        room_type  price  \
# 0          Hyde Park  41.787900 -87.587800     Private room    114
# ...

# %%
location=df['name'].str.split('in', expand=True)

# %%
location[0].unique()
# Out:
# array(['Condo ', 'Rental unit ', 'Boutique hotel ', 'Loft ', 'Home ',
#        'Place to stay ', 'Guest suite ', 'Hostel ', 'Bungalow ',
#        'Townhouse ', 'Serviced apartment ', 'Aparthotel ', 'Guesthouse ',
#        'Farm stay ', 'Bed and breakfast ', 'Cottage ', 'T', 'Hotel ',
#        'Villa ', 'Boat ', 'casa particular ', 'Vacation home ', 'Cab',
#        'm', 'Tent ', 'Religious build', 'Resort ', 'Earthen home ',
#        'Floor ', 'Houseboat ', 'Camper/RV ', 'Campsite '], dtype=object)

# %%
location[1].unique()
# Out:
# array([' Chicago ', ' Evanston ', ' Pilsen, Chicago ', ' Oak Park ',
#        ' Chicago Heights ', ' Chicago  ', ' Calumet Park ', 'y home ',
#        ' Bucktown, Chicago ', ' Oak Lawn ', ' Chicago, IL ',
#        ' Rogers Park ', ' Santa Barbara ', ' Harwood Heights ',
#        ' Evergreen Park ', ' Berwyn ', ' The Bronx ', ' ', ' Norridge ',
#        'su ', ' Riverdale ', ' Elmwood Park ', ' New Orleans ', ' Arabi ',
#        '  Uptown, New Orleans ', ' Waggaman ', 'g ',
#        ' ByWater-Marigny, New Orleans ',
#        ' ByWater-Marigny, New Orleans  ', ' New Orleans, Louisiana, US ',
#        ' New orleans ', ' New Orleans, Louisiana ', ' New Orleans, ',
#        ' New Orleans  ', ' Gretna ', ' Terrytown '], dtype=object)

# %%
location[2].unique()
# Out:
# array([None, ' Chicago ', ' New Orleans ', ' Gretna '], dtype=object)

# %%
location[location[1]=='g ']
# Out:
#                    0   1              2
# 408  Religious build  g    New Orleans

# %%
location[location[2]==' Chicago ']
# Out:
#         0        1          2
# 835     T  y home    Chicago
# 1854    T  y home    Chicago
# 1855    T  y home    Chicago
# 3120    T  y home    Chicago
# 5687    T  y home    Chicago
# 5693  Cab            Chicago
# 6228    m      su    Chicago
# 7456    T  y home    Chicago
# 8258    T  y home    Chicago

# %%
df
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name              neighbourhood   latitude  \
# 0                          Rebecca                  Hyde Park  41.787900
# ...

# %%
df['name'].unique()
# Out:
# array(['Condo in Chicago ', 'Rental unit in Chicago ',
#        'Boutique hotel in Chicago ', 'Loft in Chicago ',
#        'Home in Chicago ', 'Place to stay in Chicago ',
#        'Guest suite in Chicago ', 'Rental unit in Evanston ',
#        'Hostel in Chicago ', 'Bungalow in Chicago ',
#        'Townhouse in Chicago ', 'Serviced apartment in Chicago ',
#        'Aparthotel in Chicago ', 'Guesthouse in Chicago ',
#        'Rental unit in Pilsen, Chicago ', 'Home in Oak Park ',
#        'Farm stay in Chicago ', 'Rental unit in Chicago Heights ',
#        'Hostel in Chicago  ', 'Bed and breakfast in Chicago ',
#        'Cottage in Chicago ', 'Rental unit in Calumet Park ',
#        'Rental unit in Chicago  ', 'Tiny home in Chicago ',
#        'Home in Bucktown, Chicago ', 'Home in Oak Lawn ',
#        'Serviced apartment in Chicago, IL ', 'Townhouse in Chicago  ',
#        'Townhouse in Calumet Park ', 'Hotel in Chicago ',
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365',
#        'number_of_reviews_ltm', 'license', 'rating', 'bedrooms', 'beds',
#        'baths', 'city'],
#       dtype='object')

# %%
df['name']=df['name'].str.strip()

# %%
df.str.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[237], line 1
# ----> 1 df.str.strip()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365',
#        'number_of_reviews_ltm', 'license', 'rating', 'bedrooms', 'beds',
#        'baths', 'city'],
#       dtype='object')

# %%
df['host_name']=df['host_name'].str.strip()

# %%
df['neighbourhood']=df['neighbourhood'].str.strip()
df['neighbourhood']
# Out:
# 0                       Hyde Park
# 1                       West Town
# 2                    Lincoln Park
# 3                    Lincoln Park
# 4                    Lincoln Park
#                   ...
# 6778    Central Business District
# 6779              Treme - Lafitte
# 6780                     West End
# 6781                   St. Claude
# 6782                      Audubon
# Name: neighbourhood, Length: 15311, dtype: object

# %%
df['city']
# Out:
# 0            Chicago
# 1            Chicago
# 2            Chicago
# 3            Chicago
# 4            Chicago
#             ...
# 6778     New Orleans
# 6779     New Orleans
# 6780     New Orleans
# 6781     New Orleans
# 6782     New Orleans
# Name: city, Length: 15311, dtype: object

# %%
df=df.drop(columns=['city'])

# %%
df
# Out:
#                       id                        name    host_id  \
# 0                   2384            Condo in Chicago       2613
# 1                   7126      Rental unit in Chicago      17928
# 2                  10945      Rental unit in Chicago      33004
# 3                  12140   Boutique hotel in Chicago      46734
# 4                  24833      Rental unit in Chicago     101521
# ...                  ...                         ...        ...
# 6778  970848339775836367        Condo in New Orleans  442915263
# 6779  971022630551974985  Rental unit in New Orleans  428276486
# 6780  971622427724347438         Home in New Orleans   68337970
# 6781  971690279215450436         Home in New Orleans   14988904
# 6782  971756233356699947  Rental unit in New Orleans   33076245
#
#                          host_name              neighbourhood   latitude  \
# 0                          Rebecca                  Hyde Park  41.787900
# ...

# %%
df['host_name'].unique()
# Out:
# array(['Rebecca', 'Sarah', 'At Home Inn', ..., 'Abe', 'Lucky Inn Hotel',
#        'Edgar'], dtype=object)

# %%
df['room_type']=df['room_type'].str.replace('Entire home/apt','Appartment')

# %%
df
# Out:
#                       id                        name    host_id  \
# 0                   2384            Condo in Chicago       2613
# 1                   7126      Rental unit in Chicago      17928
# 2                  10945      Rental unit in Chicago      33004
# 3                  12140   Boutique hotel in Chicago      46734
# 4                  24833      Rental unit in Chicago     101521
# ...                  ...                         ...        ...
# 6778  970848339775836367        Condo in New Orleans  442915263
# 6779  971022630551974985  Rental unit in New Orleans  428276486
# 6780  971622427724347438         Home in New Orleans   68337970
# 6781  971690279215450436         Home in New Orleans   14988904
# 6782  971756233356699947  Rental unit in New Orleans   33076245
#
#                          host_name              neighbourhood   latitude  \
# 0                          Rebecca                  Hyde Park  41.787900
# ...

# %%
df['name'].unique()
# Out:
# array(['Condo in Chicago', 'Rental unit in Chicago',
#        'Boutique hotel in Chicago', 'Loft in Chicago', 'Home in Chicago',
#        'Place to stay in Chicago', 'Guest suite in Chicago',
#        'Rental unit in Evanston', 'Hostel in Chicago',
#        'Bungalow in Chicago', 'Townhouse in Chicago',
#        'Serviced apartment in Chicago', 'Aparthotel in Chicago',
#        'Guesthouse in Chicago', 'Rental unit in Pilsen, Chicago',
#        'Home in Oak Park', 'Farm stay in Chicago',
#        'Rental unit in Chicago Heights', 'Bed and breakfast in Chicago',
#        'Cottage in Chicago', 'Rental unit in Calumet Park',
#        'Tiny home in Chicago', 'Home in Bucktown, Chicago',
#        'Home in Oak Lawn', 'Serviced apartment in Chicago, IL',
#        'Townhouse in Calumet Park', 'Hotel in Chicago',
#        'Rental unit in Rogers Park', 'Villa in Santa Barbara',
#        'Villa in Chicago', 'Condo in Harwood Heights',
#        'Condo in Evergreen Park', 'Boat in Chicago',
# ...

# %%
location
# Out:
#                     0              1     2
# 0              Condo        Chicago   None
# 1        Rental unit        Chicago   None
# 2        Rental unit        Chicago   None
# 3     Boutique hotel        Chicago   None
# 4        Rental unit        Chicago   None
# ...               ...            ...   ...
# 6778           Condo    New Orleans   None
# 6779     Rental unit    New Orleans   None
# 6780            Home    New Orleans   None
# 6781            Home    New Orleans   None
# 6782     Rental unit    New Orleans   None
#
# [15311 rows x 3 columns]

# %%
location.loc[408,2]
# Out:
# 408             None
# 408     New Orleans
# Name: 2, dtype: object

# %%
location.loc[408,0]=='Religious building'

# %%
location.shape
# Out:
# (15311, 3)

# %%
df
# Out:
#                       id                        name    host_id  \
# 0                   2384            Condo in Chicago       2613
# 1                   7126      Rental unit in Chicago      17928
# 2                  10945      Rental unit in Chicago      33004
# 3                  12140   Boutique hotel in Chicago      46734
# 4                  24833      Rental unit in Chicago     101521
# ...                  ...                         ...        ...
# 6778  970848339775836367        Condo in New Orleans  442915263
# 6779  971022630551974985  Rental unit in New Orleans  428276486
# 6780  971622427724347438         Home in New Orleans   68337970
# 6781  971690279215450436         Home in New Orleans   14988904
# 6782  971756233356699947  Rental unit in New Orleans   33076245
#
#                          host_name              neighbourhood   latitude  \
# 0                          Rebecca                  Hyde Park  41.787900
# ...

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
df.tail(10)
# Out:
#                       id                        name    host_id  \
# 6773  970284735243895819  Rental unit in New Orleans  112910785
# 6774  970345482178053018  Rental unit in New Orleans  459381826
# 6775  970477256509726691         Home in New Orleans  101652405
# 6776  970492926565985488         Home in New Orleans  190373951
# 6777  970788678205383146           Home in Terrytown  167418116
# 6778  970848339775836367        Condo in New Orleans  442915263
# 6779  971022630551974985  Rental unit in New Orleans  428276486
# 6780  971622427724347438         Home in New Orleans   68337970
# 6781  971690279215450436         Home in New Orleans   14988904
# 6782  971756233356699947  Rental unit in New Orleans   33076245
#
#                          host_name              neighbourhood   latitude  \
# 6773                       Marigny                      Touro  29.926780
# 6774                       Allison             French Quarter  29.957080
# ...

# %%
location.loc[408,2]
# Out:
# 408             None
# 408     New Orleans
# Name: 2, dtype: object

# %%
df['name'].unique()
# Out:
# array(['Condo in Chicago', 'Rental unit in Chicago',
#        'Boutique hotel in Chicago', 'Loft in Chicago', 'Home in Chicago',
#        'Place to stay in Chicago', 'Guest suite in Chicago',
#        'Rental unit in Evanston', 'Hostel in Chicago',
#        'Bungalow in Chicago', 'Townhouse in Chicago',
#        'Serviced apartment in Chicago', 'Aparthotel in Chicago',
#        'Guesthouse in Chicago', 'Rental unit in Pilsen, Chicago',
#        'Home in Oak Park', 'Farm stay in Chicago',
#        'Rental unit in Chicago Heights', 'Bed and breakfast in Chicago',
#        'Cottage in Chicago', 'Rental unit in Calumet Park',
#        'Tiny home in Chicago', 'Home in Bucktown, Chicago',
#        'Home in Oak Lawn', 'Serviced apartment in Chicago, IL',
#        'Townhouse in Calumet Park', 'Hotel in Chicago',
#        'Rental unit in Rogers Park', 'Villa in Santa Barbara',
#        'Villa in Chicago', 'Condo in Harwood Heights',
#        'Condo in Evergreen Park', 'Boat in Chicago',
# ...

# %%
location[0].unique()
# Out:
# array(['Condo ', 'Rental unit ', 'Boutique hotel ', 'Loft ', 'Home ',
#        'Place to stay ', 'Guest suite ', 'Hostel ', 'Bungalow ',
#        'Townhouse ', 'Serviced apartment ', 'Aparthotel ', 'Guesthouse ',
#        'Farm stay ', 'Bed and breakfast ', 'Cottage ', 'T', 'Hotel ',
#        'Villa ', 'Boat ', 'casa particular ', 'Vacation home ', 'Cab',
#        'm', 'Tent ', 'Religious build', 'Resort ', 'Earthen home ',
#        'Floor ', 'Houseboat ', 'Camper/RV ', 'Campsite '], dtype=object)

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  1.531100e+04  1.531100e+04  15311.000000  15311.000000  15311.000000
# mean   3.290655e+17  1.755173e+08     36.605550    -88.730493    198.546209
# std    3.902640e+17  1.644326e+08      5.928168      1.198975    278.890457
# min    2.384000e+03  9.710000e+02     29.897680    -90.137480     12.000000
# 25%    3.000865e+07  3.494976e+07     29.963850    -90.071510     89.000000
# 50%    5.087212e+07  1.074344e+08     41.799537    -87.716328    134.000000
# 75%    7.353523e+17  2.987698e+08     41.900809    -87.652741    215.000000
# max    9.782649e+17  5.365148e+08     42.022200    -87.528420  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    15311.000000       15311.000000       15311.000000
# mean        15.527595          54.769643           1.545203
# std         32.824771          91.206256           1.966499
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365',
#        'number_of_reviews_ltm', 'license', 'rating', 'bedrooms', 'beds',
#        'baths'],
#       dtype='object')

# %%
df['last_review'].isnull().sum()
# Out:
# 2650

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       2650
# reviews_per_month                    0
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           2430
# rating                               0
# bedrooms                             0
# beds                                32
# baths                             3333
# dtype: int64

# %%
df[df['beds'].isnull()]
# Out:
#                       id                              name    host_id  \
# 1052            20503258            Rental unit in Chicago   68127227
# 2583            40114673            Rental unit in Chicago   13309390
# 2954            43543457                   Loft in Chicago  336504529
# 2955            43544239                   Loft in Chicago  336504529
# 3120            45487005              Tiny home in Chicago    6962723
# 3272            46810444            Rental unit in Chicago   10890984
# 3320            47332851                  Condo in Chicago  377006981
# 3465            48608759     Serviced apartment in Chicago  177188450
# 3586            49228404                  Condo in Chicago  195836701
# 3601            49296209            Rental unit in Chicago   35873650
# 3641            49567370     Serviced apartment in Chicago  177188450
# 3655            49626817            Rental unit in Chicago  400238857
# ...

# %%
df[df['baths'].isnull()]
# Out:
#                       id                        name    host_id    host_name  \
# 48                956609      Rental unit in Chicago    4091924         Olga
# 69               1417110            Condo in Chicago    7622794         Leah
# 82               1732652      Rental unit in Chicago    3965428          Rob
# 93               1931880      Rental unit in Chicago    4995578       George
# 94               1939467      Rental unit in Chicago    8292749         Ilya
# ...                  ...                         ...        ...          ...
# 6501  920327969316397530  Rental unit in New Orleans  185244265      Anthony
# 6502  920330387758816000  Rental unit in New Orleans  177156271      Richard
# 6505  920431116783231782  Rental unit in New Orleans   90527221  Christopher
# 6507  920442400003420453  Rental unit in New Orleans  401298124           Vi
# 6508  921080596632534506  Rental unit in New Orleans  188726923        Keely
#
# ...

# %%
df.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                      int64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# number_of_reviews_ltm                      int64
# license                                   object
# rating                                    object
# bedrooms                                  object
# ...

# %%
df['bedrooms'].str.astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[281], line 1
# ----> 1 df['bedrooms'].str.astype(int)
#
# AttributeError: 'StringMethods' object has no attribute 'astype'

# %%
df['bedrooms'].unique()
# Out:
# array([' 1 ', ' 2 ', ' 3 ', ' 4 ', ' Studio ', ' 6 ', ' 5 ', ' 7 ', ' 8 ',
#        ' 13 ', ' 10 ', ' 21 ', ' 1 private ', ' 20 ', ' 11 ', ' Half-',
#        ' 1 shared ', ' 1.5 shared ', ' 0 ', ' 9 ', ' 24 ', ' 16 ', ' 12 ',
#        ' 25 ', ' 14 ', ' Studio', ' 15 ', ' 31 ', ' 19 ', ' 22 '],
#       dtype=object)

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
df['minimum_nights'].max()
# Out:
# 1125

# %%
df['minimum_nights'].min()
# Out:
# 1

# %%
df['minimum_nights'].mean()
# Out:
# 15.527594539873293

# %%
df[df['minimum_nights']=='1']
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm, license, rating, bedrooms, beds, baths]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365',
#        'number_of_reviews_ltm', 'license', 'rating', 'bedrooms', 'beds',
#        'baths'],
#       dtype='object')

# %%
data[data['minimum_nights']=='1']
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm, license, rating, bedrooms, beds, baths, city]
# Index: []
#
# [0 rows x 23 columns]

# %%
df
# Out:
#                       id                        name    host_id  \
# 0                   2384            Condo in Chicago       2613
# 1                   7126      Rental unit in Chicago      17928
# 2                  10945      Rental unit in Chicago      33004
# 3                  12140   Boutique hotel in Chicago      46734
# 4                  24833      Rental unit in Chicago     101521
# ...                  ...                         ...        ...
# 6778  970848339775836367        Condo in New Orleans  442915263
# 6779  971022630551974985  Rental unit in New Orleans  428276486
# 6780  971622427724347438         Home in New Orleans   68337970
# 6781  971690279215450436         Home in New Orleans   14988904
# 6782  971756233356699947  Rental unit in New Orleans   33076245
#
#                          host_name              neighbourhood   latitude  \
# 0                          Rebecca                  Hyde Park  41.787900
# ...

# %%
df.to_csv('Airbnb.trial1.csv', index=False)

# %%
df.to_csv('Airbnb.trial1.xlsx', index=False)

# %%
df['rating']=df['rating'].str.replace('★','')

# %%
df['rating']=df['rating'].str.strip()

# %%
df.to_csv('Airbnb.trial2.csv', index=False)

# %%
df['rating'].unique()
# Out:
# array(['4.99', '4.70', '4.65', '4.93', '4.29', '4.30', '4.77', '4.88',
#        '5.0', '4.78', '4.95', '4.90', '4.91', '4.84', '4.74', '4.96',
#        '4.85', '4.52', '4.72', '4.81', '4.92', '4.54', '4.98', '4.94',
#        '4.87', '4.66', '4.26', '2 bedrooms', '4.97', '4.68', '4.17',
#        '4.36', '4.0', '4.67', '4.31', '4.64', '4.43', '4.61', '4.60',
#        '4.40', 'New', '4.89', '4.83', '4.82', '4.75', '4.71', '4.79',
#        '4.48', '4.58', '1 bedroom', '4.69', '4.47', '4.53', '4.80',
#        '3.67', '4.25', '4.73', '4.57', '4.49', '4.86', '4.55', '4.76',
#        '4.38', '3 bedrooms', '4.44', '4.56', '4.63', '4.41', '4.62',
#        '4.45', 'Studio', '4.24', '4.37', '4.46', '4.51', '4.59', '4.33',
#        '4.42', '5 bedrooms', '4.50', '4.16', '4.20', '3.25', '3.75',
#        '3.71', '4.27', '4 bedrooms', '4.32', '4.35', '4.28', '4.22',
#        '0.0', '3.70', '4.39', '4.34', '7 bedrooms', '9 bedrooms', '4.15',
# ...

# %%
data
# Out:
#                       id                         name    host_id  \
# 0                   2384            Condo in Chicago        2613
# 1                   7126      Rental unit in Chicago       17928
# 2                  10945      Rental unit in Chicago       33004
# 3                  12140   Boutique hotel in Chicago       46734
# 4                  24833      Rental unit in Chicago      101521
# ...                  ...                          ...        ...
# 6778  970848339775836367        Condo in New Orleans   442915263
# 6779  971022630551974985  Rental unit in New Orleans   428276486
# 6780  971622427724347438         Home in New Orleans    68337970
# 6781  971690279215450436         Home in New Orleans    14988904
# 6782  971756233356699947  Rental unit in New Orleans    33076245
#
#                          host_name  neighbourhood_group  \
# 0                          Rebecca                  NaN
# 1                            Sarah                  NaN
# ...

# %%
data1=pd.read_csv('listings(Chicago).csv')
data2=pd.read_csv('listings(new orelano).csv')
df=pd.concat([data1,data2])

# %%
df
# Out:
#                       id                                               name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df['name']=df['name'].str.strip()

# %%
df
# Out:
#                       id                                               name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df['name'].unique()
# Out:
# array(['Condo in Chicago · ★4.99 · 1 bedroom · 1 bed · 1 shared bath',
#        'Rental unit in Chicago · ★4.70 · 1 bedroom · 1 bed · 1 bath',
#        'Rental unit in Chicago · ★4.65 · 2 bedrooms · 2 beds · 1 bath',
#        ..., 'Home in New Orleans · ★New · 2 bedrooms · 2 beds · 3 baths',
#        'Home in Terrytown · ★New · 4 bedrooms · 4 beds · 2 baths',
#        'Rental unit in New Orleans · ★New · 4 bedrooms · 5 beds · 2 baths'],
#       dtype=object)

# %%
df['name'].sample()
# Out:
# 1856    Condo in Chicago · ★4.40 · 2 bedrooms · 4 beds...
# Name: name, dtype: object

# %%
specis=df['name'].str.split('★', expand=True)

# %%
specis
# Out:
#                                   0                                          1
# 0               Condo in Chicago ·    4.99 · 1 bedroom · 1 bed · 1 shared bath
# 1         Rental unit in Chicago ·           4.70 · 1 bedroom · 1 bed · 1 bath
# 2         Rental unit in Chicago ·         4.65 · 2 bedrooms · 2 beds · 1 bath
# 3      Boutique hotel in Chicago ·   4.93 · 1 bedroom · 1 bed · 1 private bath
# 4         Rental unit in Chicago ·           4.29 · 1 bedroom · 1 bed · 1 bath
# ...                             ...                                        ...
# 6778        Condo in New Orleans ·           New · 1 bedroom · 2 beds · 1 bath
# 6779  Rental unit in New Orleans ·            New · 1 bedroom · 1 bed · 1 bath
# 6780         Home in New Orleans ·         New · 2 bedrooms · 3 beds · 2 baths
# 6781         Home in New Orleans ·         New · 3 bedrooms · 3 beds · 2 baths
# 6782  Rental unit in New Orleans ·         New · 4 bedrooms · 5 beds · 2 baths
#
# ...

# %%
specis[1].unique()
# Out:
# array(['4.99 · 1 bedroom · 1 bed · 1 shared bath',
#        '4.70 · 1 bedroom · 1 bed · 1 bath',
#        '4.65 · 2 bedrooms · 2 beds · 1 bath', ...,
#        'New · 11 bedrooms · 11 beds · 8 baths',
#        'New · 2 bedrooms · 2 beds · 4 baths',
#        'New · 11 bedrooms · 13 beds · 15 baths'], dtype=object)

# %%
specis[0].unique()
# Out:
# array(['Condo in Chicago · ', 'Rental unit in Chicago · ',
#        'Boutique hotel in Chicago · ', 'Loft in Chicago · ',
#        'Home in Chicago · ', 'Place to stay in Chicago · ',
#        'Guest suite in Chicago · ',
#        'Rental unit in Chicago · 2 bedrooms · 2 beds · 2 baths',
#        'Rental unit in Evanston · ', 'Hostel in Chicago · ',
#        'Condo in Chicago · 2 bedrooms · 2 beds · 1 bath',
#        'Bungalow in Chicago · ',
#        'Rental unit in Chicago · 1 bedroom · 1 bed · 1 bath',
#        'Rental unit in Chicago · 1 bedroom · 1 bed · 1 shared bath',
#        'Townhouse in Chicago · ', 'Serviced apartment in Chicago · ',
#        'Aparthotel in Chicago · ', 'Guesthouse in Chicago · ',
#        'Condo in Chicago · 3 bedrooms · 4 beds · 3.5 baths',
#        'Condo in Chicago · 2 bedrooms · 2 beds · 2 baths',
#        'Home in Chicago · 2 bedrooms · 2 beds · 2.5 baths',
#        'Rental unit in Pilsen, Chicago · ',
# ...

# %%
df
# Out:
#                       id                                               name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.name.str.strip()
# Out:
# 0       Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1       Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2       Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3       Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4       Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
#                               ...
# 6778    Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779    Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780    Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781    Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782    Rental unit in New Orleans · ★New · 4 bedrooms...
# Name: name, Length: 15311, dtype: object

# %%
df
# Out:
#                       id                                               name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df['host_name'].str.strip()
# Out:
# 0                            Rebecca
# 1                              Sarah
# 2                        At Home Inn
# 3                    Shay And Robert
# 4                                Red
#                     ...
# 6778    Hosteeva California Building
# 6779                         Freedom
# 6780                          Yvonne
# 6781                             Lee
# 6782                          Arachu
# Name: host_name, Length: 15311, dtype: object

# %%
df=df.drop(columns=['neighbourhood_group'])

# %%
# Out:
#                     0              1     2
# 0              Condo        Chicago   None
# 1        Rental unit        Chicago   None
# 2        Rental unit        Chicago   None
# 3     Boutique hotel        Chicago   None
# 4        Rental unit        Chicago   None
# ...               ...            ...   ...
# 6778           Condo    New Orleans   None
# 6779     Rental unit    New Orleans   None
# 6780            Home    New Orleans   None
# 6781            Home    New Orleans   None
# 6782     Rental unit    New Orleans   None
#
# [15311 rows x 3 columns]

# %%
specis
# Out:
#                                   0                                          1
# 0               Condo in Chicago ·    4.99 · 1 bedroom · 1 bed · 1 shared bath
# 1         Rental unit in Chicago ·           4.70 · 1 bedroom · 1 bed · 1 bath
# 2         Rental unit in Chicago ·         4.65 · 2 bedrooms · 2 beds · 1 bath
# 3      Boutique hotel in Chicago ·   4.93 · 1 bedroom · 1 bed · 1 private bath
# 4         Rental unit in Chicago ·           4.29 · 1 bedroom · 1 bed · 1 bath
# ...                             ...                                        ...
# 6778        Condo in New Orleans ·           New · 1 bedroom · 2 beds · 1 bath
# 6779  Rental unit in New Orleans ·            New · 1 bedroom · 1 bed · 1 bath
# 6780         Home in New Orleans ·         New · 2 bedrooms · 3 beds · 2 baths
# 6781         Home in New Orleans ·         New · 3 bedrooms · 3 beds · 2 baths
# 6782  Rental unit in New Orleans ·         New · 4 bedrooms · 5 beds · 2 baths
#
# ...

# %%
specis[0].unique()
# Out:
# array(['Condo in Chicago · ', 'Rental unit in Chicago · ',
#        'Boutique hotel in Chicago · ', 'Loft in Chicago · ',
#        'Home in Chicago · ', 'Place to stay in Chicago · ',
#        'Guest suite in Chicago · ',
#        'Rental unit in Chicago · 2 bedrooms · 2 beds · 2 baths',
#        'Rental unit in Evanston · ', 'Hostel in Chicago · ',
#        'Condo in Chicago · 2 bedrooms · 2 beds · 1 bath',
#        'Bungalow in Chicago · ',
#        'Rental unit in Chicago · 1 bedroom · 1 bed · 1 bath',
#        'Rental unit in Chicago · 1 bedroom · 1 bed · 1 shared bath',
#        'Townhouse in Chicago · ', 'Serviced apartment in Chicago · ',
#        'Aparthotel in Chicago · ', 'Guesthouse in Chicago · ',
#        'Condo in Chicago · 3 bedrooms · 4 beds · 3.5 baths',
#        'Condo in Chicago · 2 bedrooms · 2 beds · 2 baths',
#        'Home in Chicago · 2 bedrooms · 2 beds · 2.5 baths',
#        'Rental unit in Pilsen, Chicago · ',
# ...

# %%
type=df['name'].str.split('·', expand=True)

# %%
type
# Out:
#                                 0        1             2         3  \
# 0               Condo in Chicago    ★4.99     1 bedroom     1 bed
# 1         Rental unit in Chicago    ★4.70     1 bedroom     1 bed
# 2         Rental unit in Chicago    ★4.65    2 bedrooms    2 beds
# 3      Boutique hotel in Chicago    ★4.93     1 bedroom     1 bed
# 4         Rental unit in Chicago    ★4.29     1 bedroom     1 bed
# ...                           ...      ...           ...       ...
# 6778        Condo in New Orleans     ★New     1 bedroom    2 beds
# 6779  Rental unit in New Orleans     ★New     1 bedroom     1 bed
# 6780         Home in New Orleans     ★New    2 bedrooms    3 beds
# 6781         Home in New Orleans     ★New    3 bedrooms    3 beds
# 6782  Rental unit in New Orleans     ★New    4 bedrooms    5 beds
#
#                     4
# 0       1 shared bath
# 1              1 bath
# 2              1 bath
# 3      1 private bath
# 4              1 bath
# ...               ...
# ...

# %%
type[0].unique()
# Out:
# array(['Condo in Chicago ', 'Rental unit in Chicago ',
#        'Boutique hotel in Chicago ', 'Loft in Chicago ',
#        'Home in Chicago ', 'Place to stay in Chicago ',
#        'Guest suite in Chicago ', 'Rental unit in Evanston ',
#        'Hostel in Chicago ', 'Bungalow in Chicago ',
#        'Townhouse in Chicago ', 'Serviced apartment in Chicago ',
#        'Aparthotel in Chicago ', 'Guesthouse in Chicago ',
#        'Rental unit in Pilsen, Chicago ', 'Home in Oak Park ',
#        'Farm stay in Chicago ', 'Rental unit in Chicago Heights ',
#        'Hostel in Chicago  ', 'Bed and breakfast in Chicago ',
#        'Cottage in Chicago ', 'Rental unit in Calumet Park ',
#        'Rental unit in Chicago  ', 'Tiny home in Chicago ',
#        'Home in Bucktown, Chicago ', 'Home in Oak Lawn ',
#        'Serviced apartment in Chicago, IL ', 'Townhouse in Chicago  ',
#        'Townhouse in Calumet Park ', 'Hotel in Chicago ',
# ...

# %%
type[1].unique()
# Out:
# array([' ★4.99 ', ' ★4.70 ', ' ★4.65 ', ' ★4.93 ', ' ★4.29 ', ' ★4.30 ',
#        ' ★4.77 ', ' ★4.88 ', ' ★5.0 ', ' ★4.78 ', ' ★4.95 ', ' ★4.90 ',
#        ' ★4.91 ', ' ★4.84 ', ' ★4.74 ', ' ★4.96 ', ' ★4.85 ', ' ★4.52 ',
#        ' ★4.72 ', ' ★4.81 ', ' ★4.92 ', ' ★4.54 ', ' ★4.98 ', ' ★4.94 ',
#        ' ★4.87 ', ' ★4.66 ', ' ★4.26 ', ' 2 bedrooms ', ' ★4.97 ',
#        ' ★4.68 ', ' ★4.17 ', ' ★4.36 ', ' ★4.0 ', ' ★4.67 ', ' ★4.31 ',
#        ' ★4.64 ', ' ★4.43 ', ' ★4.61 ', ' ★4.60 ', ' ★4.40 ', ' ★New ',
#        ' ★4.89 ', ' ★4.83 ', ' ★4.82 ', ' ★4.75 ', ' ★4.71 ', ' ★4.79 ',
#        ' ★4.48 ', ' ★4.58 ', ' 1 bedroom ', ' ★4.69 ', ' ★4.47 ',
#        ' ★4.53 ', ' ★4.80 ', ' ★3.67 ', ' ★4.25 ', ' ★4.73 ', ' ★4.57 ',
#        ' ★4.49 ', ' ★4.86 ', ' ★4.55 ', ' ★4.76 ', ' ★4.38 ',
#        ' 3 bedrooms ', ' ★4.44 ', ' ★4.56 ', ' ★4.63 ', ' ★4.41 ',
#        ' ★4.62 ', ' ★4.45 ', ' Studio ', ' ★4.24 ', ' ★4.37 ', ' ★4.46 ',
# ...

# %%
type[type[2]=='bedroom']
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4]
# Index: []

# %%
type.loc[25,2]
# Out:
# 25     2 bedrooms
# 25         Studio
# Name: 2, dtype: object

# %%
type[1].dtypes
# Out:
# dtype('O')

# %%
type.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# dtype: object

# %%
type[1]=type[1].str.replace('bedrooms','beds')

# %%
type[1].unique()
# Out:
# array([' ★4.99 ', ' ★4.70 ', ' ★4.65 ', ' ★4.93 ', ' ★4.29 ', ' ★4.30 ',
#        ' ★4.77 ', ' ★4.88 ', ' ★5.0 ', ' ★4.78 ', ' ★4.95 ', ' ★4.90 ',
#        ' ★4.91 ', ' ★4.84 ', ' ★4.74 ', ' ★4.96 ', ' ★4.85 ', ' ★4.52 ',
#        ' ★4.72 ', ' ★4.81 ', ' ★4.92 ', ' ★4.54 ', ' ★4.98 ', ' ★4.94 ',
#        ' ★4.87 ', ' ★4.66 ', ' ★4.26 ', ' 2 beds ', ' ★4.97 ', ' ★4.68 ',
#        ' ★4.17 ', ' ★4.36 ', ' ★4.0 ', ' ★4.67 ', ' ★4.31 ', ' ★4.64 ',
#        ' ★4.43 ', ' ★4.61 ', ' ★4.60 ', ' ★4.40 ', ' ★New ', ' ★4.89 ',
#        ' ★4.83 ', ' ★4.82 ', ' ★4.75 ', ' ★4.71 ', ' ★4.79 ', ' ★4.48 ',
#        ' ★4.58 ', ' 1 bedroom ', ' ★4.69 ', ' ★4.47 ', ' ★4.53 ',
#        ' ★4.80 ', ' ★3.67 ', ' ★4.25 ', ' ★4.73 ', ' ★4.57 ', ' ★4.49 ',
#        ' ★4.86 ', ' ★4.55 ', ' ★4.76 ', ' ★4.38 ', ' 3 beds ', ' ★4.44 ',
#        ' ★4.56 ', ' ★4.63 ', ' ★4.41 ', ' ★4.62 ', ' ★4.45 ', ' Studio ',
#        ' ★4.24 ', ' ★4.37 ', ' ★4.46 ', ' ★4.51 ', ' ★4.59 ', ' ★4.33 ',
# ...

# %%
beds=['bedroom','beds']
type[type[1].isin(beds)]
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4]
# Index: []

# %%
type[type[0].isin('芝加哥')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[383], line 1
# ----> 1 type[type[0].isin('芝加哥')]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:5563, in Series.isin(self, values)
#    5490 def isin(self, values) -> Series:
#    5491     """
#    5492     Whether elements in Series are contained in `values`.
#    5493
#    (...)
#    5561     dtype: bool
#    5562     """
# -> 5563     result = algorithms.isin(self._values, values)
#    5564     return self._constructor(result, index=self.index).__finalize__(
#    5565         self, method="isin"
#    5566     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:459, in isin(comps, values)
#     454     raise TypeError(
#     455         "only list-like objects are allowed to be passed "
#     456         f"to isin(), you passed a [{type(comps).__name__}]"
#     457     )
# ...

# %%
chica='芝加哥'
type[type[0].isin(chica)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[384], line 2
#       1 chica='芝加哥'
# ----> 2 type[type[0].isin(chica)]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:5563, in Series.isin(self, values)
#    5490 def isin(self, values) -> Series:
#    5491     """
#    5492     Whether elements in Series are contained in `values`.
#    5493
#    (...)
#    5561     dtype: bool
#    5562     """
# -> 5563     result = algorithms.isin(self._values, values)
#    5564     return self._constructor(result, index=self.index).__finalize__(
#    5565         self, method="isin"
#    5566     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:459, in isin(comps, values)
#     454     raise TypeError(
#     455         "only list-like objects are allowed to be passed "
#     456         f"to isin(), you passed a [{type(comps).__name__}]"
# ...

# %%
df['name']
# Out:
# 0       Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1       Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2       Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3       Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4       Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
#                               ...
# 6778    Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779    Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780    Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781    Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782    Rental unit in New Orleans · ★New · 4 bedrooms...
# Name: name, Length: 15311, dtype: object

# %%
df[df['name'] == 'Rental unit in 芝加哥 ']
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm, license]
# Index: []

# %%
df
# Out:
#                       id                                               name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
type
# Out:
#                                 0      1             2         3  \
# 0               Condo in Chicago   ★4.99    1 bedroom     1 bed
# 1         Rental unit in Chicago   ★4.70    1 bedroom     1 bed
# 2         Rental unit in Chicago   ★4.65   2 bedrooms    2 beds
# 3      Boutique hotel in Chicago   ★4.93    1 bedroom     1 bed
# 4         Rental unit in Chicago   ★4.29    1 bedroom     1 bed
# ...                           ...    ...           ...       ...
# 6778        Condo in New Orleans    ★New    1 bedroom    2 beds
# 6779  Rental unit in New Orleans    ★New    1 bedroom     1 bed
# 6780         Home in New Orleans    ★New   2 bedrooms    3 beds
# 6781         Home in New Orleans    ★New   3 bedrooms    3 beds
# 6782  Rental unit in New Orleans    ★New   4 bedrooms    5 beds
#
#                     4
# 0       1 shared bath
# 1              1 bath
# 2              1 bath
# 3      1 private bath
# 4              1 bath
# ...               ...
# 6778           1 bath
# ...

# %%
type[0].unique()
# Out:
# array(['Condo in Chicago ', 'Rental unit in Chicago ',
#        'Boutique hotel in Chicago ', 'Loft in Chicago ',
#        'Home in Chicago ', 'Place to stay in Chicago ',
#        'Guest suite in Chicago ', 'Rental unit in Evanston ',
#        'Hostel in Chicago ', 'Bungalow in Chicago ',
#        'Townhouse in Chicago ', 'Serviced apartment in Chicago ',
#        'Aparthotel in Chicago ', 'Guesthouse in Chicago ',
#        'Rental unit in Pilsen, Chicago ', 'Home in Oak Park ',
#        'Farm stay in Chicago ', 'Rental unit in Chicago Heights ',
#        'Hostel in Chicago  ', 'Bed and breakfast in Chicago ',
#        'Cottage in Chicago ', 'Rental unit in Calumet Park ',
#        'Rental unit in Chicago  ', 'Tiny home in Chicago ',
#        'Home in Bucktown, Chicago ', 'Home in Oak Lawn ',
#        'Serviced apartment in Chicago, IL ', 'Townhouse in Chicago  ',
#        'Townhouse in Calumet Park ', 'Hotel in Chicago ',
# ...

# %%
type[0]=type[0].str.strip()

# %%
type=type.rename(columns={0:'name'})

# %%
type
# Out:
#                             name      1             2         3  \
# 0               Condo in Chicago  ★4.99    1 bedroom     1 bed
# 1         Rental unit in Chicago  ★4.70    1 bedroom     1 bed
# 2         Rental unit in Chicago  ★4.65   2 bedrooms    2 beds
# 3      Boutique hotel in Chicago  ★4.93    1 bedroom     1 bed
# 4         Rental unit in Chicago  ★4.29    1 bedroom     1 bed
# ...                          ...    ...           ...       ...
# 6778        Condo in New Orleans   ★New    1 bedroom    2 beds
# 6779  Rental unit in New Orleans   ★New    1 bedroom     1 bed
# 6780         Home in New Orleans   ★New   2 bedrooms    3 beds
# 6781         Home in New Orleans   ★New   3 bedrooms    3 beds
# 6782  Rental unit in New Orleans   ★New   4 bedrooms    5 beds
#
#                     4
# 0       1 shared bath
# 1              1 bath
# 2              1 bath
# 3      1 private bath
# 4              1 bath
# ...               ...
# 6778           1 bath
# ...

# %%
df=df.rename(columns={'name':'site_name'})

# %%
df
# Out:
#                       id                                          site_name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df['name']=type['name']

# %%
df
# Out:
#                       id                                          site_name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
type[1].unique()
# Out:
# array(['★4.99', '★4.70', '★4.65', '★4.93', '★4.29', '★4.30', '★4.77',
#        '★4.88', '★5.0', '★4.78', '★4.95', '★4.90', '★4.91', '★4.84',
#        '★4.74', '★4.96', '★4.85', '★4.52', '★4.72', '★4.81', '★4.92',
#        '★4.54', '★4.98', '★4.94', '★4.87', '★4.66', '★4.26', '2 beds',
#        '★4.97', '★4.68', '★4.17', '★4.36', '★4.0', '★4.67', '★4.31',
#        '★4.64', '★4.43', '★4.61', '★4.60', '★4.40', '★New', '★4.89',
#        '★4.83', '★4.82', '★4.75', '★4.71', '★4.79', '★4.48', '★4.58',
#        '1 bedroom', '★4.69', '★4.47', '★4.53', '★4.80', '★3.67', '★4.25',
#        '★4.73', '★4.57', '★4.49', '★4.86', '★4.55', '★4.76', '★4.38',
#        '3 beds', '★4.44', '★4.56', '★4.63', '★4.41', '★4.62', '★4.45',
#        'Studio', '★4.24', '★4.37', '★4.46', '★4.51', '★4.59', '★4.33',
#        '★4.42', '5 beds', '★4.50', '★4.16', '★4.20', '★3.25', '★3.75',
#        '★3.71', '★4.27', '4 beds', '★4.32', '★4.35', '★4.28', '★4.22',
# ...

# %%
df['rating']=type[1]

# %%
df
# Out:
#                       id                                          site_name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df['rating']=df['rating'].str.replace('★','')

# %%
df
# Out:
#                       id                                          site_name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df['rating']=df['rating'].str.replace('New','0')

# %%
df['rating'].unique()
# Out:
# array(['4.99', '4.70', '4.65', '4.93', '4.29', '4.30', '4.77', '4.88',
#        '5.0', '4.78', '4.95', '4.90', '4.91', '4.84', '4.74', '4.96',
#        '4.85', '4.52', '4.72', '4.81', '4.92', '4.54', '4.98', '4.94',
#        '4.87', '4.66', '4.26', '2 beds', '4.97', '4.68', '4.17', '4.36',
#        '4.0', '4.67', '4.31', '4.64', '4.43', '4.61', '4.60', '4.40', '0',
#        '4.89', '4.83', '4.82', '4.75', '4.71', '4.79', '4.48', '4.58',
#        '1 bedroom', '4.69', '4.47', '4.53', '4.80', '3.67', '4.25',
#        '4.73', '4.57', '4.49', '4.86', '4.55', '4.76', '4.38', '3 beds',
#        '4.44', '4.56', '4.63', '4.41', '4.62', '4.45', 'Studio', '4.24',
#        '4.37', '4.46', '4.51', '4.59', '4.33', '4.42', '5 beds', '4.50',
#        '4.16', '4.20', '3.25', '3.75', '3.71', '4.27', '4 beds', '4.32',
#        '4.35', '4.28', '4.22', '0.0', '3.70', '4.39', '4.34', '7 beds',
#        '9 beds', '4.15', '6 beds', '4.18', '4.13', '3.79', '4.11', '3.0',
# ...

# %%
df['rating']=df['rating'].str.replace('1 bedroom','0')
df['rating']=df['rating'].str.replace('3 beds','0')
df['rating']=df['rating'].str.replace('Studio','0')
df['rating']=df['rating'].str.replace('5 beds','0')
df['rating']=df['rating'].str.replace('4 beds','0')
df['rating']=df['rating'].str.replace('7 beds','0')
df['rating']=df['rating'].str.replace('12 beds','0')

# %%
df['rating'].unique()
# Out:
# array(['4.99', '4.70', '4.65', '4.93', '4.29', '4.30', '4.77', '4.88',
#        '5.0', '4.78', '4.95', '4.90', '4.91', '4.84', '4.74', '4.96',
#        '4.85', '4.52', '4.72', '4.81', '4.92', '4.54', '4.98', '4.94',
#        '4.87', '4.66', '4.26', '2 beds', '4.97', '4.68', '4.17', '4.36',
#        '4.0', '4.67', '4.31', '4.64', '4.43', '4.61', '4.60', '4.40', '0',
#        '4.89', '4.83', '4.82', '4.75', '4.71', '4.79', '4.48', '4.58',
#        '4.69', '4.47', '4.53', '4.80', '3.67', '4.25', '4.73', '4.57',
#        '4.49', '4.86', '4.55', '4.76', '4.38', '4.44', '4.56', '4.63',
#        '4.41', '4.62', '4.45', '4.24', '4.37', '4.46', '4.51', '4.59',
#        '4.33', '4.42', '4.50', '4.16', '4.20', '3.25', '3.75', '3.71',
#        '4.27', '4.32', '4.35', '4.28', '4.22', '0.0', '3.70', '4.39',
#        '4.34', '9 beds', '4.15', '6 beds', '4.18', '4.13', '3.79', '4.11',
#        '3.0', '3.77', '3.33', '3.98', '4.12', '4.09', '3.88', '8 beds',
# ...

# %%
df['rating']=df['rating'].str.replace('2 beds','0')
df['rating']=df['rating'].str.replace('11 beds','0')
df['rating']=df['rating'].str.replace('6 beds','0')
df['rating']=df['rating'].str.replace('9 beds','0')
df['rating']=df['rating'].str.replace('19 beds','0')
df['rating']=df['rating'].str.replace('10 beds','0')
df['rating']=df['rating'].str.replace('1 bed','0')

# %%
df['rating']
# Out:
# 0       4.99
# 1       4.70
# 2       4.65
# 3       4.93
# 4       4.29
#         ...
# 6778       0
# 6779       0
# 6780       0
# 6781       0
# 6782       0
# Name: rating, Length: 15311, dtype: object

# %%
df
# Out:
#                       id                                          site_name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df['room_type']=df['room_type'].str.strip()

# %%
df['neighbourhood']=df['neighbourhood'].str.strip()

# %%
df['name'].unique()
# Out:
# array(['Condo in Chicago', 'Rental unit in Chicago',
#        'Boutique hotel in Chicago', 'Loft in Chicago', 'Home in Chicago',
#        'Place to stay in Chicago', 'Guest suite in Chicago',
#        'Rental unit in Evanston', 'Hostel in Chicago',
#        'Bungalow in Chicago', 'Townhouse in Chicago',
#        'Serviced apartment in Chicago', 'Aparthotel in Chicago',
#        'Guesthouse in Chicago', 'Rental unit in Pilsen, Chicago',
#        'Home in Oak Park', 'Farm stay in Chicago',
#        'Rental unit in Chicago Heights', 'Bed and breakfast in Chicago',
#        'Cottage in Chicago', 'Rental unit in Calumet Park',
#        'Tiny home in Chicago', 'Home in Bucktown, Chicago',
#        'Home in Oak Lawn', 'Serviced apartment in Chicago, IL',
#        'Townhouse in Calumet Park', 'Hotel in Chicago',
#        'Rental unit in Rogers Park', 'Villa in Santa Barbara',
#        'Villa in Chicago', 'Condo in Harwood Heights',
# ...

# %%
df[df['name']=='Chicago']
# Out:
# Empty DataFrame
# Columns: [id, site_name, host_id, host_name, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm, license, name, rating]
# Index: []

# %%
data1[data1['name']=='Chicago']
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm, license]
# Index: []

# %%
df['name']=df['name'].str.replace(', IL','')

# %%
df['name'].unique()
# Out:
# array(['Condo in Chicago', 'Rental unit in Chicago',
#        'Boutique hotel in Chicago', 'Loft in Chicago', 'Home in Chicago',
#        'Place to stay in Chicago', 'Guest suite in Chicago',
#        'Rental unit in Evanston', 'Hostel in Chicago',
#        'Bungalow in Chicago', 'Townhouse in Chicago',
#        'Serviced apartment in Chicago', 'Aparthotel in Chicago',
#        'Guesthouse in Chicago', 'Rental unit in Pilsen, Chicago',
#        'Home in Oak Park', 'Farm stay in Chicago',
#        'Rental unit in Chicago Heights', 'Bed and breakfast in Chicago',
#        'Cottage in Chicago', 'Rental unit in Calumet Park',
#        'Tiny home in Chicago', 'Home in Bucktown, Chicago',
#        'Home in Oak Lawn', 'Townhouse in Calumet Park',
#        'Hotel in Chicago', 'Rental unit in Rogers Park',
#        'Villa in Santa Barbara', 'Villa in Chicago',
#        'Condo in Harwood Heights', 'Rental unit in 芝加哥',
#        'Condo in Evergreen Park', 'Boat in Chicago',
# ...

# %%
df.dtypes
# Out:
# id                                  int64
# site_name                          object
# host_id                             int64
# host_name                          object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# name                               object
# rating                             object
# dtype: object

# %%
df['rating'].str.astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[437], line 1
# ----> 1 df['rating'].str.astype(float)
#
# AttributeError: 'StringMethods' object has no attribute 'astype'

# %%
df['rating'].unique()
# Out:
# array(['4.99', '4.70', '4.65', '4.93', '4.29', '4.30', '4.77', '4.88',
#        '5.0', '4.78', '4.95', '4.90', '4.91', '4.84', '4.74', '4.96',
#        '4.85', '4.52', '4.72', '4.81', '4.92', '4.54', '4.98', '4.94',
#        '4.87', '4.66', '4.26', '0', '4.97', '4.68', '4.17', '4.36', '4.0',
#        '4.67', '4.31', '4.64', '4.43', '4.61', '4.60', '4.40', '4.89',
#        '4.83', '4.82', '4.75', '4.71', '4.79', '4.48', '4.58', '4.69',
#        '4.47', '4.53', '4.80', '3.67', '4.25', '4.73', '4.57', '4.49',
#        '4.86', '4.55', '4.76', '4.38', '4.44', '4.56', '4.63', '4.41',
#        '4.62', '4.45', '4.24', '4.37', '4.46', '4.51', '4.59', '4.33',
#        '4.42', '4.50', '4.16', '4.20', '3.25', '3.75', '3.71', '4.27',
#        '4.32', '4.35', '4.28', '4.22', '0.0', '3.70', '4.39', '4.34',
#        '4.15', '4.18', '4.13', '3.79', '4.11', '3.0', '3.77', '3.33',
#        '3.98', '4.12', '4.09', '3.88', '3.90', '3.40', '4.14', '4.04',
# ...

# %%
df['rating']=df['rating'].str.replace('8 beds','0')

# %%
df['rating'].str.astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[441], line 1
# ----> 1 df['rating'].str.astype(float)
#
# AttributeError: 'StringMethods' object has no attribute 'astype'

# %%
df['rating']/100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:129, in _evaluate_numexpr(op, op_str, a, b)
#     128 if result is None:
# --> 129     result = _evaluate_standard(op, op_str, a, b)
#     131 return result
#
# ...

# %%
df=df.drop(columns=['rating'])

# %%
df
# Out:
#                       id                                          site_name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df['rating'].unique()
# Out:
# array(['4.99', '4.70', '4.65', '4.93', '4.29', '4.30', '4.77', '4.88',
#        '5.0', '4.78', '4.95', '4.90', '4.91', '4.84', '4.74', '4.96',
#        '4.85', '4.52', '4.72', '4.81', '4.92', '4.54', '4.98', '4.94',
#        '4.87', '4.66', '4.26', '0', '4.97', '4.68', '4.17', '4.36', '4.0',
#        '4.67', '4.31', '4.64', '4.43', '4.61', '4.60', '4.40', '4.89',
#        '4.83', '4.82', '4.75', '4.71', '4.79', '4.48', '4.58', '4.69',
#        '4.47', '4.53', '4.80', '3.67', '4.25', '4.73', '4.57', '4.49',
#        '4.86', '4.55', '4.76', '4.38', '4.44', '4.56', '4.63', '4.41',
#        '4.62', '4.45', '4.24', '4.37', '4.46', '4.51', '4.59', '4.33',
#        '4.42', '4.50', '4.16', '4.20', '3.25', '3.75', '3.71', '4.27',
#        '4.32', '4.35', '4.28', '4.22', '0.0', '3.70', '4.39', '4.34',
#        '4.15', '4.18', '4.13', '3.79', '4.11', '3.0', '3.77', '3.33',
#        '3.98', '4.12', '4.09', '3.88', '3.90', '3.40', '4.14', '4.04',
# ...

# %%
round(df['rating'],1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[464], line 1
# ----> 1 round(df['rating'],1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:1658, in NDFrame.__round__(self, decimals)
#    1656 @final
#    1657 def __round__(self: NDFrameT, decimals: int = 0) -> NDFrameT:
# -> 1658     return self.round(decimals).__finalize__(self, method="__round__")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:2602, in Series.round(self, decimals, *args, **kwargs)
#    2570 """
#    2571 Round each value in a Series to the given number of decimals.
#    2572
#    (...)
#    2599 dtype: float64
#    2600 """
#    2601 nv.validate_round(args, kwargs)
# -> 2602 result = self._values.round(decimals)
#    2603 result = self._constructor(result, index=self.index).__finalize__(
#    2604     self, method="round"
#    2605 )
#    2607 return result
#
# ...

# %%
df['rating'].dtypes
# Out:
# dtype('O')

# %%
df['rating'].str.astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[469], line 1
# ----> 1 df['rating'].str.astype(float)
#
# AttributeError: 'StringMethods' object has no attribute 'astype'

# %%
df.dtypes
# Out:
# id                                  int64
# site_name                          object
# host_id                             int64
# host_name                          object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# name                               object
# rating                             object
# dtype: object

# %%
df['rating']=df['rating'].str.strip()

# %%
df['rating']=df['rating'].astype(float)

# %%
df['rating'].unique()
# Out:
# array([ 4.99,  4.7 ,  4.65,  4.93,  4.29,  4.3 ,  4.77,  4.88,  5.  ,
#         4.78,  4.95,  4.9 ,  4.91,  4.84,  4.74,  4.96,  4.85,  4.52,
#         4.72,  4.81,  4.92,  4.54,  4.98,  4.94,  4.87,  4.66,  4.26,
#         0.  ,  4.97,  4.68,  4.17,  4.36,  4.  ,  4.67,  4.31,  4.64,
#         4.43,  4.61,  4.6 ,  4.4 ,  4.89,  4.83,  4.82,  4.75,  4.71,
#         4.79,  4.48,  4.58,  4.69,  4.47,  4.53,  4.8 ,  3.67,  4.25,
#         4.73,  4.57,  4.49,  4.86,  4.55,  4.76,  4.38,  4.44,  4.56,
#         4.63,  4.41,  4.62,  4.45,  4.24,  4.37,  4.46,  4.51,  4.59,
#         4.33,  4.42,  4.5 ,  4.16,  4.2 ,  3.25,  3.75,  3.71,  4.27,
#         4.32,  4.35,  4.28,  4.22,  3.7 ,  4.39,  4.34,  4.15,  4.18,
#         4.13,  3.79,  4.11,  3.  ,  3.77,  3.33,  3.98,  4.12,  4.09,
#         3.88,  3.9 ,  3.4 ,  4.14,  4.04,  3.8 ,  4.08,  4.19,  4.06,
#         4.05,  3.6 ,  4.21,  3.47,  3.94,  3.58,  3.86,  2.5 ,  3.95,
# ...

# %%
round(df['rating'],0).unique()
# Out:
# array([ 5.,  4.,  0.,  3.,  2., 10., 20.])

# %%
df['rating'].replace('.','').unique()
# Out:
# array([ 4.99,  4.7 ,  4.65,  4.93,  4.29,  4.3 ,  4.77,  4.88,  5.  ,
#         4.78,  4.95,  4.9 ,  4.91,  4.84,  4.74,  4.96,  4.85,  4.52,
#         4.72,  4.81,  4.92,  4.54,  4.98,  4.94,  4.87,  4.66,  4.26,
#         0.  ,  4.97,  4.68,  4.17,  4.36,  4.  ,  4.67,  4.31,  4.64,
#         4.43,  4.61,  4.6 ,  4.4 ,  4.89,  4.83,  4.82,  4.75,  4.71,
#         4.79,  4.48,  4.58,  4.69,  4.47,  4.53,  4.8 ,  3.67,  4.25,
#         4.73,  4.57,  4.49,  4.86,  4.55,  4.76,  4.38,  4.44,  4.56,
#         4.63,  4.41,  4.62,  4.45,  4.24,  4.37,  4.46,  4.51,  4.59,
#         4.33,  4.42,  4.5 ,  4.16,  4.2 ,  3.25,  3.75,  3.71,  4.27,
#         4.32,  4.35,  4.28,  4.22,  3.7 ,  4.39,  4.34,  4.15,  4.18,
#         4.13,  3.79,  4.11,  3.  ,  3.77,  3.33,  3.98,  4.12,  4.09,
#         3.88,  3.9 ,  3.4 ,  4.14,  4.04,  3.8 ,  4.08,  4.19,  4.06,
#         4.05,  3.6 ,  4.21,  3.47,  3.94,  3.58,  3.86,  2.5 ,  3.95,
# ...

# %%
df
# Out:
#                       id                                          site_name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df['name'].unique()
# Out:
# array(['Condo in Chicago', 'Rental unit in Chicago',
#        'Boutique hotel in Chicago', 'Loft in Chicago', 'Home in Chicago',
#        'Place to stay in Chicago', 'Guest suite in Chicago',
#        'Rental unit in Evanston', 'Hostel in Chicago',
#        'Bungalow in Chicago', 'Townhouse in Chicago',
#        'Serviced apartment in Chicago', 'Aparthotel in Chicago',
#        'Guesthouse in Chicago', 'Rental unit in Pilsen, Chicago',
#        'Home in Oak Park', 'Farm stay in Chicago',
#        'Rental unit in Chicago Heights', 'Bed and breakfast in Chicago',
#        'Cottage in Chicago', 'Rental unit in Calumet Park',
#        'Tiny home in Chicago', 'Home in Bucktown, Chicago',
#        'Home in Oak Lawn', 'Serviced apartment in Chicago, IL',
#        'Townhouse in Calumet Park', 'Hotel in Chicago',
#        'Rental unit in Rogers Park', 'Villa in Santa Barbara',
#        'Villa in Chicago', 'Condo in Harwood Heights',
# ...

# %%
city=df['name'].str.split('in', expand=True)

# %%
city=city.rename(columns={0:'name',1:'city'})

# %%
city
# Out:
#                  name          city     2
# 0              Condo        Chicago  None
# 1        Rental unit        Chicago  None
# 2        Rental unit        Chicago  None
# 3     Boutique hotel        Chicago  None
# 4        Rental unit        Chicago  None
# ...               ...           ...   ...
# 6778           Condo    New Orleans  None
# 6779     Rental unit    New Orleans  None
# 6780            Home    New Orleans  None
# 6781            Home    New Orleans  None
# 6782     Rental unit    New Orleans  None
#
# [15311 rows x 3 columns]

# %%
city['name'].unique()
# Out:
# array(['Condo ', 'Rental unit ', 'Boutique hotel ', 'Loft ', 'Home ',
#        'Place to stay ', 'Guest suite ', 'Hostel ', 'Bungalow ',
#        'Townhouse ', 'Serviced apartment ', 'Aparthotel ', 'Guesthouse ',
#        'Farm stay ', 'Bed and breakfast ', 'Cottage ', 'T', 'Hotel ',
#        'Villa ', 'Boat ', 'casa particular ', 'Vacation home ', 'Cab',
#        'm', 'Tent ', 'Religious build', 'Resort ', 'Earthen home ',
#        'Floor ', 'Houseboat ', 'Camper/RV ', 'Campsite '], dtype=object)

# %%
city['city'].unique()
# Out:
# array([' Chicago', ' Evanston', ' Pilsen, Chicago', ' Oak Park',
#        ' Chicago Heights', ' Calumet Park', 'y home ',
#        ' Bucktown, Chicago', ' Oak Lawn', ' Chicago, IL', ' Rogers Park',
#        ' Santa Barbara', ' Harwood Heights', ' 芝加哥', ' Evergreen Park',
#        ' Berwyn', ' The Bronx', ' ', ' Norridge', 'su ', ' Riverdale',
#        ' Elmwood Park', ' New Orleans', ' Arabi', '  Uptown, New Orleans',
#        ' Waggaman', 'g ', ' ByWater-Marigny, New Orleans',
#        ' New Orleans, Louisiana, US', ' New orleans',
#        ' New Orleans, Louisiana', ' New Orleans,', ' Gretna',
#        ' Terrytown'], dtype=object)

# %%
# Out:
# array([' Chicago', ' Evanston', ' Pilsen, Chicago', ' Oak Park',
#        ' Chicago Heights', ' Calumet Park', 'y home ',
#        ' Bucktown, Chicago', ' Oak Lawn', ' Rogers Park',
#        ' Santa Barbara', ' Harwood Heights', ' 芝加哥', ' Evergreen Park',
#        ' Berwyn', ' The Bronx', ' ', ' Norridge', 'su ', ' Riverdale',
#        ' Elmwood Park', ' New Orleans', ' Arabi', '  Uptown, New Orleans',
#        ' Waggaman', 'g ', ' ByWater-Marigny, New Orleans',
#        ' New Orleans, Louisiana, US', ' New orleans',
#        ' New Orleans, Louisiana', ' New Orleans,', ' Gretna',
#        ' Terrytown'], dtype=object)

# %%
city
# Out:
#                  name          city     2
# 0              Condo        Chicago  None
# 1        Rental unit        Chicago  None
# 2        Rental unit        Chicago  None
# 3     Boutique hotel        Chicago  None
# 4        Rental unit        Chicago  None
# ...               ...           ...   ...
# 6778           Condo    New Orleans  None
# 6779     Rental unit    New Orleans  None
# 6780            Home    New Orleans  None
# 6781            Home    New Orleans  None
# 6782     Rental unit    New Orleans  None
#
# [15311 rows x 3 columns]

# %%
city[2].unique()
# Out:
# array([None, ' Chicago', ' New Orleans', ' Gretna'], dtype=object)

# %%
df
# Out:
#                       id                                          site_name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df['new_name']=city['name']
df['city']=city['city']

# %%
df
# Out:
#                       id                                          site_name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df=df.rename(columns={'new_name':'type'})

# %%
df
# Out:
#                       id                                          site_name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df[2]=city[2]

# %%
df
# Out:
#                       id                                          site_name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df
# Out:
#                       id                                          site_name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df['type']=df['type'].str.strip()

# %%
df['city']=df['city'].str.strip()

# %%
df[2]=df[2].str.strip()

# %%
df
# Out:
#                       id                                          site_name  \
# 0                   2384  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1                   7126  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2                  10945  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3                  12140  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4                  24833  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...                  ...                                                ...
# 6778  970848339775836367  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 6779  971022630551974985  Rental unit in New Orleans · ★New · 1 bedroom ...
# 6780  971622427724347438  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 6781  971690279215450436  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 6782  971756233356699947  Rental unit in New Orleans · ★New · 4 bedrooms...
#
# ...

# %%
df.to_csv('Airbnb_trial.csv', index=False)

# %%
df['type'].unique()
# Out:
# array(['Condo', 'Rental unit', 'Boutique hotel', 'Loft', 'Home',
#        'Place to stay', 'Guest suite', 'Hostel', 'Bungalow', 'Townhouse',
#        'Serviced apartment', 'Aparthotel', 'Guesthouse', 'Farm stay',
#        'Bed and breakfast', 'Cottage', 'T', 'Hotel', 'Villa', 'Boat',
#        'casa particular', 'Vacation home', 'Cab', 'm', 'Tent',
#        'Religious build', 'Resort', 'Earthen home', 'Floor', 'Houseboat',
#        'Camper/RV', 'Campsite'], dtype=object)

# %%
df['type']=df['type'].str.replace('Tiny','Tiny home')

# %%
df['type']=df['type'].str.replace('minsu','m')

# %%
df['type'].unique()
# Out:
# array(['Condo', 'Rental unit', 'Boutique hotel', 'Loft', 'Home',
#        'Place to stay', 'Guest suite', 'Hostel', 'Bungalow',
#        'Tiny homeownhouse', 'Serviced apartment', 'Aparthotel',
#        'Guesthouse', 'Farm stay', 'Bed and breakfast', 'Cottage',
#        'Tiny home', 'Hotel', 'Villa', 'Boat', 'casa particular',
#        'Vacation home', 'Cab', 'm', 'Tiny homeent', 'Religious build',
#        'Resort', 'Earthen home', 'Floor', 'Houseboat', 'Camper/RV',
#        'Campsite'], dtype=object)

# %%
df=pd.read_csv('Airbnb_trial.csv')

# %%
df
# Out:
#                  id                                          site_name  \
# 0      2.384000e+03  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1      7.126000e+03  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2      1.094500e+04  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3      1.214000e+04  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4      2.483300e+04  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...             ...                                                ...
# 15306  9.708480e+17  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 15307  9.710230e+17  Rental unit in New Orleans · ★New · 1 bedroom ...
# 15308  9.716220e+17  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 15309  9.716900e+17  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 15310  9.717560e+17  Rental unit in New Orleans · ★New · 4 bedrooms...
#
#          host_id                     host_name              neighbourhood  \
# ...

# %%
df['city'].unique()
# Out:
# array(['Chicago', 'Evanston', 'Oak Park', 'Chicago Heights',
#        'Calumet Park', 'Oak Lawn', 'Rogers Park', 'Santa Barbara',
#        'Harwood Heights', 'Evergreen Park', 'Berwyn', 'The Bronx',
#        'Norridge', 'Riverdale', 'Elmwood Park', 'New Orleans', 'Arabi',
#        'Waggaman', 'New orleans', 'New Orleans,', 'Gretna', 'Terrytown'],
#       dtype=object)

# %%
df.duplicated().sum()
# Out:
# 18

# %%
df.drop_duplicates()
# Out:
#                  id                                          site_name  \
# 0      2.384000e+03  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1      7.126000e+03  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2      1.094500e+04  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3      1.214000e+04  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4      2.483300e+04  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...             ...                                                ...
# 15306  9.708480e+17  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 15307  9.710230e+17  Rental unit in New Orleans · ★New · 1 bedroom ...
# 15308  9.716220e+17  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 15309  9.716900e+17  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 15310  9.717560e+17  Rental unit in New Orleans · ★New · 4 bedrooms...
#
#          host_id                     host_name              neighbourhood  \
# ...

# %%
df[df.drop_duplicates()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[534], line 1
# ----> 1 df[df.drop_duplicates()]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3794, in DataFrame.__getitem__(self, key)
#    3792 # Do we have a (boolean) DataFrame?
#    3793 if isinstance(key, DataFrame):
# -> 3794     return self.where(key)
#    3796 # Do we have a (boolean) 1d indexer?
#    3797 if com.is_bool_indexer(key):
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
# ...

# %%
df[df.duplicated]
# Out:
#                  id                                          site_name  \
# 13789  7.142700e+17  Resort in New Orleans · 1 bedroom · 2 beds · 1...
# 13792  7.142700e+17  Resort in New Orleans · 1 bedroom · 2 beds · 1...
# 13793  7.142700e+17  Resort in New Orleans · 1 bedroom · 2 beds · 1...
# 13796  7.142710e+17  Resort in New Orleans · 2 bedrooms · 3 beds · ...
# 13832  7.167420e+17  Resort in New Orleans · 1 bedroom · 2 beds · 1...
# 14675  8.528970e+17    Condo in New Orleans · Studio · 2 beds · 1 bath
# 14677  8.528970e+17    Condo in New Orleans · Studio · 2 beds · 1 bath
# 14680  8.528970e+17  Condo in New Orleans · 1 bedroom · 2 beds · 1 ...
# 14681  8.528970e+17  Condo in New Orleans · 1 bedroom · 2 beds · 1 ...
# 14682  8.528970e+17  Condo in New Orleans · 1 bedroom · 2 beds · 1 ...
# 14685  8.528980e+17  Condo in New Orleans · 2 bedrooms · 4 beds · 2...
# 14686  8.528980e+17  Condo in New Orleans · 2 bedrooms · 4 beds · 2...
# ...

# %%
df.duplicated().sum()
# Out:
# 18

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['site_name']
# Out:
# 0        Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1        Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2        Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3        Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4        Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
#                                ...
# 15306    Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 15307    Rental unit in New Orleans · ★New · 1 bedroom ...
# 15308    Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 15309    Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 15310    Rental unit in New Orleans · ★New · 4 bedrooms...
# Name: site_name, Length: 15293, dtype: object

# %%
new=df['site_name'].str.split('★', expand=True)

# %%
new
# Out:
#                                    0  \
# 0                Condo in Chicago ·
# 1          Rental unit in Chicago ·
# 2          Rental unit in Chicago ·
# 3       Boutique hotel in Chicago ·
# 4          Rental unit in Chicago ·
# ...                              ...
# 15306        Condo in New Orleans ·
# 15307  Rental unit in New Orleans ·
# 15308         Home in New Orleans ·
# 15309         Home in New Orleans ·
# 15310  Rental unit in New Orleans ·
#
#                                                1
# 0       4.99 · 1 bedroom · 1 bed · 1 shared bath
# 1              4.70 · 1 bedroom · 1 bed · 1 bath
# 2            4.65 · 2 bedrooms · 2 beds · 1 bath
# 3      4.93 · 1 bedroom · 1 bed · 1 private bath
# 4              4.29 · 1 bedroom · 1 bed · 1 bath
# ...                                          ...
# 15306          New · 1 bedroom · 2 beds · 1 bath
# 15307           New · 1 bedroom · 1 bed · 1 bath
# 15308        New · 2 bedrooms · 3 beds · 2 baths
# ...

# %%
new.0.unique()
# Out:
#   Cell In[546], line 1
#     new.0.unique()
#        ^
# SyntaxError: invalid syntax

# %%
new[0].unique()
# Out:
# array(['Condo in Chicago · ', 'Rental unit in Chicago · ',
#        'Boutique hotel in Chicago · ', 'Loft in Chicago · ',
#        'Home in Chicago · ', 'Place to stay in Chicago · ',
#        'Guest suite in Chicago · ',
#        'Rental unit in Chicago · 2 bedrooms · 2 beds · 2 baths',
#        'Rental unit in Evanston · ', 'Hostel in Chicago · ',
#        'Condo in Chicago · 2 bedrooms · 2 beds · 1 bath',
#        'Bungalow in Chicago · ',
#        'Rental unit in Chicago · 1 bedroom · 1 bed · 1 bath',
#        'Rental unit in Chicago · 1 bedroom · 1 bed · 1 shared bath',
#        'Townhouse in Chicago · ', 'Serviced apartment in Chicago · ',
#        'Aparthotel in Chicago · ', 'Guesthouse in Chicago · ',
#        'Condo in Chicago · 3 bedrooms · 4 beds · 3.5 baths',
#        'Condo in Chicago · 2 bedrooms · 2 beds · 2 baths',
#        'Home in Chicago · 2 bedrooms · 2 beds · 2.5 baths',
#        'Rental unit in Pilsen, Chicago · ',
# ...

# %%
chica = new[0].str.split('Chicago',expand=True)

# %%
chica
# Out:
#                                    0     1
# 0                          Condo in     ·
# 1                    Rental unit in     ·
# 2                    Rental unit in     ·
# 3                 Boutique hotel in     ·
# 4                    Rental unit in     ·
# ...                              ...   ...
# 15306        Condo in New Orleans ·   None
# 15307  Rental unit in New Orleans ·   None
# 15308         Home in New Orleans ·   None
# 15309         Home in New Orleans ·   None
# 15310  Rental unit in New Orleans ·   None
#
# [15293 rows x 2 columns]

# %%
chica[0].unique()
# Out:
# array(['Condo in ', 'Rental unit in ', 'Boutique hotel in ', 'Loft in ',
#        'Home in ', 'Place to stay in ', 'Guest suite in ',
#        'Rental unit in Evanston · ', 'Hostel in ', 'Bungalow in ',
#        'Townhouse in ', 'Serviced apartment in ', 'Aparthotel in ',
#        'Guesthouse in ', 'Rental unit in Pilsen, ', 'Home in Oak Park · ',
#        'Farm stay in ', 'Bed and breakfast in ', 'Cottage in ',
#        'Rental unit in Calumet Park · ', 'Tiny home in ',
#        'Home in Bucktown, ', 'Home in Oak Lawn · ',
#        'Townhouse in Calumet Park · ', 'Hotel in ',
#        'Rental unit in Rogers Park · ',
#        'Villa in Santa Barbara · 3 bedrooms · 4 beds · 3 baths',
#        'Villa in ', 'Condo in Harwood Heights · ',
#        'Rental unit in 芝加哥 · ', 'Condo in Evergreen Park · ', 'Boat in ',
#        'casa particular in ', 'Vacation home in ',
#        'Rental unit in Oak Park · ', 'Home in Harwood Heights · ',
# ...

# %%
chica=chica.dropna()

# %%
chica
# Out:
#                        0    1
# 0              Condo in    ·
# 1        Rental unit in    ·
# 2        Rental unit in    ·
# 3     Boutique hotel in    ·
# 4        Rental unit in    ·
# ...                  ...  ...
# 8523     Rental unit in    ·
# 8524            Home in    ·
# 8525            Home in    ·
# 8526     Rental unit in    ·
# 8527     Rental unit in    ·
#
# [8488 rows x 2 columns]

# %%
chica[1].unique()
# Out:
# array([' , ', ' , 2 bedrooms , 2 beds , 2 baths',
#        ' , 2 bedrooms , 2 beds , 1 bath', ' , 1 bedroom , 1 bed , 1 bath',
#        ' , 1 bedroom , 1 bed , 1 shared bath',
#        ' , 3 bedrooms , 4 beds , 3.5 baths',
#        ' , 2 bedrooms , 2 beds , 2.5 baths', ' , Studio , 1 bed , 1 bath',
#        ' , 1 bedroom , 2 beds , 1 bath',
#        ' , 3 bedrooms , 2 beds , 2 baths',
#        ' , 2 bedrooms , 4 beds , 1.5 baths',
#        ' Heights , 5 bedrooms , 5 beds , 1.5 baths', '  , ',
#        ' , 2 bedrooms , 2 beds , 1.5 baths',
#        ' , 2 bedrooms , 1 bed , 1 bath',
#        ' , 5 bedrooms , 5 beds , 3.5 baths',
#        ' , 1 bedroom , 1 bed , 2 baths',
#        ' , 2 bedrooms , 3 beds , 1 bath',
#        ' , 1 bedroom , 1 bed , 2 shared baths',
#        ' , 3 bedrooms , 3 beds , 1 bath',
#        ' , Studio , 1 bed , 1 private bath',
#        ' , Studio , 3 beds , 1 shared bath',
#        ' , 1 bedroom , 1 bed , 1 private bath',
# ...

# %%
chica[1]=chica[1].str.replace('·',',')
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_15512\667377147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chica[1]=chica[1].str.replace('·',',')

# %%
chica
# Out:
#                        0    1
# 0              Condo in    ,
# 1        Rental unit in    ,
# 2        Rental unit in    ,
# 3     Boutique hotel in    ,
# 4        Rental unit in    ,
# ...                  ...  ...
# 8523     Rental unit in    ,
# 8524            Home in    ,
# 8525            Home in    ,
# 8526     Rental unit in    ,
# 8527     Rental unit in    ,
#
# [8488 rows x 2 columns]

# %%
chica[0].unique()
# Out:
# array(['Condo in ', 'Rental unit in ', 'Boutique hotel in ', 'Loft in ',
#        'Home in ', 'Place to stay in ', 'Guest suite in ', 'Hostel in ',
#        'Bungalow in ', 'Townhouse in ', 'Serviced apartment in ',
#        'Aparthotel in ', 'Guesthouse in ', 'Rental unit in Pilsen, ',
#        'Farm stay in ', 'Bed and breakfast in ', 'Cottage in ',
#        'Tiny home in ', 'Home in Bucktown, ', 'Hotel in ', 'Villa in ',
#        'Boat in ', 'casa particular in ', 'Vacation home in ',
#        'Cabin in ', 'minsu in ', 'Tent in '], dtype=object)

# %%
chica=chica.rename(columns={0:'type'})

# %%
chica
# Out:
#                     type    1
# 0              Condo in    ,
# 1        Rental unit in    ,
# 2        Rental unit in    ,
# 3     Boutique hotel in    ,
# 4        Rental unit in    ,
# ...                  ...  ...
# 8523     Rental unit in    ,
# 8524            Home in    ,
# 8525            Home in    ,
# 8526     Rental unit in    ,
# 8527     Rental unit in    ,
#
# [8488 rows x 2 columns]

# %%
df
# Out:
#                  id                                          site_name  \
# 0      2.384000e+03  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1      7.126000e+03  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2      1.094500e+04  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3      1.214000e+04  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4      2.483300e+04  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...             ...                                                ...
# 15306  9.708480e+17  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 15307  9.710230e+17  Rental unit in New Orleans · ★New · 1 bedroom ...
# 15308  9.716220e+17  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 15309  9.716900e+17  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 15310  9.717560e+17  Rental unit in New Orleans · ★New · 4 bedrooms...
#
#          host_id                     host_name              neighbourhood  \
# ...

# %%
df.to_csv('Airbnb_trial2.csv', index=False)

# %%
df['neighbourhood'].unique()
# Out:
# array(['Hyde Park', 'West Town', 'Lincoln Park', 'Logan Square', 'Uptown',
#        'Edgewater', 'North Center', 'Pullman', 'Near South Side',
#        'West Ridge', 'Near West Side', 'Bridgeport', 'Kenwood',
#        'Lake View', 'Loop', 'Lincoln Square', 'Forest Glen',
#        'Near North Side', 'East Garfield Park', 'Rogers Park',
#        'North Lawndale', 'Beverly', 'Portage Park', 'Lower West Side',
#        'Woodlawn', 'Irving Park', 'Grand Boulevard', 'Washington Park',
#        'South Lawndale', 'Morgan Park', 'Dunning', 'West Lawn',
#        'South Shore', 'Humboldt Park', 'Armour Square',
#        'West Garfield Park', 'Hermosa', 'Mckinley Park', 'Douglas',
#        'Avondale', 'Hegewisch', 'West Elsdon', 'Ashburn',
#        'Greater Grand Crossing', 'Belmont Cragin', 'Norwood Park',
#        'Garfield Ridge', 'Austin', 'North Park', 'Oakland',
#        'West Pullman', 'Archer Heights', 'Jefferson Park', 'Edison Park',
# ...

# %%
df['neighbourhood']=df['neighbourhood'].str.strip()
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_15512\1949088056.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['neighbourhood']=df['neighbourhood'].str.strip()

# %%
df
# Out:
#                  id                                          site_name  \
# 0      2.384000e+03  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1      7.126000e+03  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2      1.094500e+04  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3      1.214000e+04  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4      2.483300e+04  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...             ...                                                ...
# 15306  9.708480e+17  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 15307  9.710230e+17  Rental unit in New Orleans · ★New · 1 bedroom ...
# 15308  9.716220e+17  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 15309  9.716900e+17  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 15310  9.717560e+17  Rental unit in New Orleans · ★New · 4 bedrooms...
#
#          host_id                     host_name              neighbourhood  \
# ...

# %%
new[1]=new[1].str.replace('·',',')

# %%
new[1]
# Out:
# 0         4.99 , 1 bedroom , 1 bed , 1 shared bath
# 1                4.70 , 1 bedroom , 1 bed , 1 bath
# 2              4.65 , 2 bedrooms , 2 beds , 1 bath
# 3        4.93 , 1 bedroom , 1 bed , 1 private bath
# 4                4.29 , 1 bedroom , 1 bed , 1 bath
#                            ...
# 15306            New , 1 bedroom , 2 beds , 1 bath
# 15307             New , 1 bedroom , 1 bed , 1 bath
# 15308          New , 2 bedrooms , 3 beds , 2 baths
# 15309          New , 3 bedrooms , 3 beds , 2 baths
# 15310          New , 4 bedrooms , 5 beds , 2 baths
# Name: 1, Length: 15293, dtype: object

# %%
df['property']=new[1]
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_15512\3836223948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['property']=new[1]

# %%
df
# Out:
#                  id                                          site_name  \
# 0      2.384000e+03  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...
# 1      7.126000e+03  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...
# 2      1.094500e+04  Rental unit in Chicago · ★4.65 · 2 bedrooms · ...
# 3      1.214000e+04  Boutique hotel in Chicago · ★4.93 · 1 bedroom ...
# 4      2.483300e+04  Rental unit in Chicago · ★4.29 · 1 bedroom · 1...
# ...             ...                                                ...
# 15306  9.708480e+17  Condo in New Orleans · ★New · 1 bedroom · 2 be...
# 15307  9.710230e+17  Rental unit in New Orleans · ★New · 1 bedroom ...
# 15308  9.716220e+17  Home in New Orleans · ★New · 2 bedrooms · 3 be...
# 15309  9.716900e+17  Home in New Orleans · ★New · 3 bedrooms · 3 be...
# 15310  9.717560e+17  Rental unit in New Orleans · ★New · 4 bedrooms...
#
#          host_id                     host_name              neighbourhood  \
# ...

# %%
df=pd.read_csv('Airbnb_trial5.csv')

# %%
df
# Out:
#                  id                                          site_name  \
# 0      2.384000e+03  Condo in Chicago Â· â˜…4.99 Â· 1 bedroom Â· 1 ...
# 1      7.126000e+03  Rental unit in Chicago Â· â˜…4.70 Â· 1 bedroom...
# 2      1.094500e+04  Rental unit in Chicago Â· â˜…4.65 Â· 2 bedroom...
# 3      1.214000e+04  Boutique hotel in Chicago Â· â˜…4.93 Â· 1 bedr...
# 4      2.483300e+04  Rental unit in Chicago Â· â˜…4.29 Â· 1 bedroom...
# ...             ...                                                ...
# 15288  9.710000e+17  Condo in New Orleans Â· â˜…New Â· 1 bedroom Â·...
# 15289  9.710000e+17  Rental unit in New Orleans Â· â˜…New Â· 1 bedr...
# 15290  9.720000e+17  Home in New Orleans Â· â˜…New Â· 2 bedrooms Â·...
# 15291  9.720000e+17  Home in New Orleans Â· â˜…New Â· 3 bedrooms Â·...
# 15292  9.720000e+17  Rental unit in New Orleans Â· â˜…New Â· 4 bedr...
#
#          host_id                     host_name              neighbourhood  \
# ...

# %%
new[1]
# Out:
# 0         4.99 , 1 bedroom , 1 bed , 1 shared bath
# 1                4.70 , 1 bedroom , 1 bed , 1 bath
# 2              4.65 , 2 bedrooms , 2 beds , 1 bath
# 3        4.93 , 1 bedroom , 1 bed , 1 private bath
# 4                4.29 , 1 bedroom , 1 bed , 1 bath
#                            ...
# 15306            New , 1 bedroom , 2 beds , 1 bath
# 15307             New , 1 bedroom , 1 bed , 1 bath
# 15308          New , 2 bedrooms , 3 beds , 2 baths
# 15309          New , 3 bedrooms , 3 beds , 2 baths
# 15310          New , 4 bedrooms , 5 beds , 2 baths
# Name: 1, Length: 15293, dtype: object

# %%
df['property']=new[1]

# %%
df
# Out:
#                  id                                          site_name  \
# 0      2.384000e+03  Condo in Chicago Â· â˜…4.99 Â· 1 bedroom Â· 1 ...
# 1      7.126000e+03  Rental unit in Chicago Â· â˜…4.70 Â· 1 bedroom...
# 2      1.094500e+04  Rental unit in Chicago Â· â˜…4.65 Â· 2 bedroom...
# 3      1.214000e+04  Boutique hotel in Chicago Â· â˜…4.93 Â· 1 bedr...
# 4      2.483300e+04  Rental unit in Chicago Â· â˜…4.29 Â· 1 bedroom...
# ...             ...                                                ...
# 15288  9.710000e+17  Condo in New Orleans Â· â˜…New Â· 1 bedroom Â·...
# 15289  9.710000e+17  Rental unit in New Orleans Â· â˜…New Â· 1 bedr...
# 15290  9.720000e+17  Home in New Orleans Â· â˜…New Â· 2 bedrooms Â·...
# 15291  9.720000e+17  Home in New Orleans Â· â˜…New Â· 3 bedrooms Â·...
# 15292  9.720000e+17  Rental unit in New Orleans Â· â˜…New Â· 4 bedr...
#
#          host_id                     host_name              neighbourhood  \
# ...

# %%
df.to_csv('Airbnb_trial6.csv', index=False)

# %%
property=df['property'].str.split(',', expand=True)

# %%
property
# Out:
#            0             1         2                3
# 0      4.99     1 bedroom     1 bed     1 shared bath
# 1      4.70     1 bedroom     1 bed            1 bath
# 2      4.65    2 bedrooms    2 beds            1 bath
# 3      4.93     1 bedroom     1 bed    1 private bath
# 4      4.29     1 bedroom     1 bed            1 bath
# ...      ...           ...       ...              ...
# 15288   New     1 bedroom     1 bed            1 bath
# 15289   New    2 bedrooms    2 beds           2 baths
# 15290   New    4 bedrooms    6 beds           2 baths
# 15291   New     1 bedroom     1 bed            1 bath
# 15292   New     1 bedroom    2 beds            1 bath
#
# [15293 rows x 4 columns]

# %%
property[1].unique()
# Out:
# array([' 1 bedroom ', ' 2 bedrooms ', ' 3 bedrooms ', ' 4 bedrooms ',
#        None, ' Studio ', ' 6 bedrooms ', ' 5 bedrooms ', ' 7 bedrooms ',
#        ' 8 bedrooms ', ' 13 bedrooms ', ' 10 bedrooms ', ' 9 bedrooms ',
#        ' 1 bath', ' 2 beds ', ' 1 bed ', ' 11 bedrooms ', ' Studio',
#        ' 15 bedrooms ', nan, ' 12 bedrooms '], dtype=object)

# %%
property = property.rename(columns={3:'beds',4:'baths'})

# %%
property
# Out:
#       new_ratings      bedrooms     baths            baths
# 0           4.99     1 bedroom     1 bed     1 shared bath
# 1           4.70     1 bedroom     1 bed            1 bath
# 2           4.65    2 bedrooms    2 beds            1 bath
# 3           4.93     1 bedroom     1 bed    1 private bath
# 4           4.29     1 bedroom     1 bed            1 bath
# ...           ...           ...       ...              ...
# 15288        New     1 bedroom     1 bed            1 bath
# 15289        New    2 bedrooms    2 beds           2 baths
# 15290        New    4 bedrooms    6 beds           2 baths
# 15291        New     1 bedroom     1 bed            1 bath
# 15292        New     1 bedroom    2 beds            1 bath
#
# [15293 rows x 4 columns]

# %%
df['bedrooms']=property['bedrooms']

# %%
df['beds'] = property['baths']
# Out:
#   Cell In[608], line 1
#     df['beds'] == df['baths'] = property['baths']
#     ^
# SyntaxError: cannot assign to comparison

# %%
new[1]
# Out:
# 0         4.99 , 1 bedroom , 1 bed , 1 shared bath
# 1                4.70 , 1 bedroom , 1 bed , 1 bath
# 2              4.65 , 2 bedrooms , 2 beds , 1 bath
# 3        4.93 , 1 bedroom , 1 bed , 1 private bath
# 4                4.29 , 1 bedroom , 1 bed , 1 bath
#                            ...
# 15306            New , 1 bedroom , 2 beds , 1 bath
# 15307             New , 1 bedroom , 1 bed , 1 bath
# 15308          New , 2 bedrooms , 3 beds , 2 baths
# 15309          New , 3 bedrooms , 3 beds , 2 baths
# 15310          New , 4 bedrooms , 5 beds , 2 baths
# Name: 1, Length: 15293, dtype: object

# %%
prop=new[1].str.split(',', expand=True)

# %%
prop
# Out:
#            0             1         2                3
# 0      4.99     1 bedroom     1 bed     1 shared bath
# 1      4.70     1 bedroom     1 bed            1 bath
# 2      4.65    2 bedrooms    2 beds            1 bath
# 3      4.93     1 bedroom     1 bed    1 private bath
# 4      4.29     1 bedroom     1 bed            1 bath
# ...      ...           ...       ...              ...
# 15306   New     1 bedroom    2 beds            1 bath
# 15307   New     1 bedroom     1 bed            1 bath
# 15308   New    2 bedrooms    3 beds           2 baths
# 15309   New    3 bedrooms    3 beds           2 baths
# 15310   New    4 bedrooms    5 beds           2 baths
#
# [15293 rows x 4 columns]

# %%
prop=prop.rename(columns={2:'beds',3:'baths'})

# %%
df['beds']=prop['beds']
df['baths']=prop['baths']

# %%
df
# Out:
#                  id                                          site_name  \
# 0      2.384000e+03  Condo in Chicago Â· â˜…4.99 Â· 1 bedroom Â· 1 ...
# 1      7.126000e+03  Rental unit in Chicago Â· â˜…4.70 Â· 1 bedroom...
# 2      1.094500e+04  Rental unit in Chicago Â· â˜…4.65 Â· 2 bedroom...
# 3      1.214000e+04  Boutique hotel in Chicago Â· â˜…4.93 Â· 1 bedr...
# 4      2.483300e+04  Rental unit in Chicago Â· â˜…4.29 Â· 1 bedroom...
# ...             ...                                                ...
# 15288  9.710000e+17  Condo in New Orleans Â· â˜…New Â· 1 bedroom Â·...
# 15289  9.710000e+17  Rental unit in New Orleans Â· â˜…New Â· 1 bedr...
# 15290  9.720000e+17  Home in New Orleans Â· â˜…New Â· 2 bedrooms Â·...
# 15291  9.720000e+17  Home in New Orleans Â· â˜…New Â· 3 bedrooms Â·...
# 15292  9.720000e+17  Rental unit in New Orleans Â· â˜…New Â· 4 bedr...
#
#          host_id                     host_name              neighbourhood  \
# ...

# %%
df.to_csv('airbnbtrial7.csv', index=False)

# %%
df
# Out:
#                  id                                          site_name  \
# 0      2.384000e+03  Condo in Chicago Â· â˜…4.99 Â· 1 bedroom Â· 1 ...
# 1      7.126000e+03  Rental unit in Chicago Â· â˜…4.70 Â· 1 bedroom...
# 2      1.094500e+04  Rental unit in Chicago Â· â˜…4.65 Â· 2 bedroom...
# 3      1.214000e+04  Boutique hotel in Chicago Â· â˜…4.93 Â· 1 bedr...
# 4      2.483300e+04  Rental unit in Chicago Â· â˜…4.29 Â· 1 bedroom...
# ...             ...                                                ...
# 15288  9.710000e+17  Condo in New Orleans Â· â˜…New Â· 1 bedroom Â·...
# 15289  9.710000e+17  Rental unit in New Orleans Â· â˜…New Â· 1 bedr...
# 15290  9.720000e+17  Home in New Orleans Â· â˜…New Â· 2 bedrooms Â·...
# 15291  9.720000e+17  Home in New Orleans Â· â˜…New Â· 3 bedrooms Â·...
# 15292  9.720000e+17  Rental unit in New Orleans Â· â˜…New Â· 4 bedr...
#
#          host_id                     host_name              neighbourhood  \
# ...

# %%
df['neighbourhood'].unique()
# Out:
# array(['Hyde Park', 'West Town', 'Lincoln Park', 'Logan Square', 'Uptown',
#        'Edgewater', 'North Center', 'Pullman', 'Near South Side',
#        'West Ridge', 'Near West Side', 'Bridgeport', 'Kenwood',
#        'Lake View', 'Loop', 'Lincoln Square', 'Forest Glen',
#        'Near North Side', 'East Garfield Park', 'Rogers Park',
#        'North Lawndale', 'Beverly', 'Portage Park', 'Lower West Side',
#        'Woodlawn', 'Irving Park', 'Grand Boulevard', 'Washington Park',
#        'South Lawndale', 'Morgan Park', 'Dunning', 'West Lawn',
#        'South Shore', 'Humboldt Park', 'Armour Square',
#        'West Garfield Park', 'Hermosa', 'Mckinley Park', 'Douglas',
#        'Avondale', 'Hegewisch', 'West Elsdon', 'Ashburn',
#        'Greater Grand Crossing', 'Belmont Cragin', 'Norwood Park',
#        'Garfield Ridge', 'Austin', 'North Park', 'Oakland',
#        'West Pullman', 'Archer Heights', 'Jefferson Park', 'Edison Park',
# ...

# %%
df['neighbourhood']=df['neighbourhood'].str.strip()

# %%
df
# Out:
#                  id                                          site_name  \
# 0      2.384000e+03  Condo in Chicago Â· â˜…4.99 Â· 1 bedroom Â· 1 ...
# 1      7.126000e+03  Rental unit in Chicago Â· â˜…4.70 Â· 1 bedroom...
# 2      1.094500e+04  Rental unit in Chicago Â· â˜…4.65 Â· 2 bedroom...
# 3      1.214000e+04  Boutique hotel in Chicago Â· â˜…4.93 Â· 1 bedr...
# 4      2.483300e+04  Rental unit in Chicago Â· â˜…4.29 Â· 1 bedroom...
# ...             ...                                                ...
# 15288  9.710000e+17  Condo in New Orleans Â· â˜…New Â· 1 bedroom Â·...
# 15289  9.710000e+17  Rental unit in New Orleans Â· â˜…New Â· 1 bedr...
# 15290  9.720000e+17  Home in New Orleans Â· â˜…New Â· 2 bedrooms Â·...
# 15291  9.720000e+17  Home in New Orleans Â· â˜…New Â· 3 bedrooms Â·...
# 15292  9.720000e+17  Rental unit in New Orleans Â· â˜…New Â· 4 bedr...
#
#          host_id                     host_name              neighbourhood  \
# ...

# %%
df=pd.read_csv('airbnbtrial7.csv')

# %%
df
# Out:
#                  id                                          site_name  \
# 0      2.384000e+03  Condo in Chicago Â· â˜…4.99 Â· 1 bedroom Â· 1 ...
# 1      7.126000e+03  Rental unit in Chicago Â· â˜…4.70 Â· 1 bedroom...
# 2      1.094500e+04  Rental unit in Chicago Â· â˜…4.65 Â· 2 bedroom...
# 3      1.214000e+04  Boutique hotel in Chicago Â· â˜…4.93 Â· 1 bedr...
# 4      2.483300e+04  Rental unit in Chicago Â· â˜…4.29 Â· 1 bedroom...
# ...             ...                                                ...
# 15288  9.710000e+17  Condo in New Orleans Â· â˜…New Â· 1 bedroom Â·...
# 15289  9.710000e+17  Rental unit in New Orleans Â· â˜…New Â· 1 bedr...
# 15290  9.720000e+17  Home in New Orleans Â· â˜…New Â· 2 bedrooms Â·...
# 15291  9.720000e+17  Home in New Orleans Â· â˜…New Â· 3 bedrooms Â·...
# 15292  9.720000e+17  Rental unit in New Orleans Â· â˜…New Â· 4 bedr...
#
#          host_id                     host_name              neighbourhood  \
# ...

# %%
df
# Out:
#                  id                                          site_name  \
# 0      2.384000e+03  Condo in Chicago Â· â˜…4.99 Â· 1 bedroom Â· 1 ...
# 1      7.126000e+03  Rental unit in Chicago Â· â˜…4.70 Â· 1 bedroom...
# 2      1.094500e+04  Rental unit in Chicago Â· â˜…4.65 Â· 2 bedroom...
# 3      1.214000e+04  Boutique hotel in Chicago Â· â˜…4.93 Â· 1 bedr...
# 4      2.483300e+04  Rental unit in Chicago Â· â˜…4.29 Â· 1 bedroom...
# ...             ...                                                ...
# 15288  9.710000e+17  Condo in New Orleans Â· â˜…New Â· 1 bedroom Â·...
# 15289  9.710000e+17  Rental unit in New Orleans Â· â˜…New Â· 1 bedr...
# 15290  9.720000e+17  Home in New Orleans Â· â˜…New Â· 2 bedrooms Â·...
# 15291  9.720000e+17  Home in New Orleans Â· â˜…New Â· 3 bedrooms Â·...
# 15292  9.720000e+17  Rental unit in New Orleans Â· â˜…New Â· 4 bedr...
#
#          host_id                     host_name              neighbourhood  \
# ...

# %%
df.duplicated().sum()
# Out:
# 12

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                  id                                          site_name  \
# 0      2.384000e+03  Condo in Chicago Â· â˜…4.99 Â· 1 bedroom Â· 1 ...
# 1      7.126000e+03  Rental unit in Chicago Â· â˜…4.70 Â· 1 bedroom...
# 2      1.094500e+04  Rental unit in Chicago Â· â˜…4.65 Â· 2 bedroom...
# 3      1.214000e+04  Boutique hotel in Chicago Â· â˜…4.93 Â· 1 bedr...
# 4      2.483300e+04  Rental unit in Chicago Â· â˜…4.29 Â· 1 bedroom...
# ...             ...                                                ...
# 15288  9.710000e+17  Condo in New Orleans Â· â˜…New Â· 1 bedroom Â·...
# 15289  9.710000e+17  Rental unit in New Orleans Â· â˜…New Â· 1 bedr...
# 15290  9.720000e+17  Home in New Orleans Â· â˜…New Â· 2 bedrooms Â·...
# 15291  9.720000e+17  Home in New Orleans Â· â˜…New Â· 3 bedrooms Â·...
# 15292  9.720000e+17  Rental unit in New Orleans Â· â˜…New Â· 4 bedr...
#
#          host_id                     host_name              neighbourhood  \
# ...

# %%
df.to_csv('airbnb0.csv', index=False)
